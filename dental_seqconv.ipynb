# %% [markdown]
# <a href="https://colab.research.google.com/github/tgialoimtr/backbone/blob/master/dental_seqconv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.18.5)

# %%
import cv2
import numpy as np
import os, sys
import json
import tensorflow as tf

# %%
# !ls "/content/gdrive/My Drive/workspace/dental/"
# Out:
# checkpoints  checkpoints2  tb  tb2

# %%
# !nvidia-smi
# Out:
# Wed Aug 19 09:18:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# 1244x(2245~2976) => 1x1.8~2.3tf.__version__
# 1350x(3118~3407) => 1x2.3~2.5

# %%
import hashlib
 
def str2col(s):
    ''' convert/hash string to color, so that it describe same string. '''
    RGBint = int(hashlib.sha1(s.encode('utf-8')).hexdigest(), 16) % (2 ** 24)
    blue =  RGBint & 255
    green = (RGBint >> 8) & 255
    red =   (RGBint >> 16) & 255
    return red, green, blue
 
def name2desc(name):
    ''' 
    FDI labeling rule: example 14x
    1 means upper-left
    4 means 4th teeth
    x: optional, in [m, g, i, e]
    -m: missing root of teeth (only top)
    -g: only root exist, missing top
    -i: implant
    -e: extended teeth (bij duw rawng)
    '''
    rs = {'top':False, 'left':False, 'major':0, 'minor':0, 'ext':None}
    rs['major'] = int(name[0])
    rs['minor'] = int(name[1])
    if name[0] == '1' or name[0] == '2':
        rs['top'] = True
    if name[0] == '3' or name[0] == '2':
        rs['left'] = True
    if len(name) > 2:
        rs['ext'] = name[2]
    return rs
 
class Contour(object):
    
    def __init__(self, name, points):
        self.name = name
        self.desc = name2desc(name)
        self.xy_points = np.array(points) # (x,y) points
        self.points = np.stack([self.xy_points[:,1], self.xy_points[:,0]], axis=1) # (y,x) points
        self.center = np.mean(self.points, axis=0)
        
    def lowest_point(self):
        lowest_point_idx = np.argmax(self.points[:,0])
        return self.points[lowest_point_idx, :]
    
    def highest_point(self):
        highest_point_idx = np.argmin(self.points[:,0])
        return self.points[highest_point_idx, :]
        
    def draw(self, img, col_str=None, what_to_draw=['contour', 'label']):
        xyi_points = self.xy_points.astype(np.int32)
        if col_str is None:
            col = str2col(self.name)
        else:
            col = str2col(col_str)
        if 'contour' in what_to_draw:
            cv2.drawContours(img, [xyi_points], -1, col, 2)
        if 'fill' in what_to_draw:
            cv2.drawContours(img, [xyi_points], -1, col, -1)
        if 'label' in what_to_draw:
            if 'fill' in what_to_draw: col = (255-col[0], 255 - col[1], 255 - col[2])
            pos = (int(self.center[1]), int(self.center[0]))
            cv2.putText(img, self.name, pos, cv2.FONT_HERSHEY_SIMPLEX, 1, col)

# %%
ext_masks = ['i', 'm', 'e', 'b', 'g']
ext_masks.index('m')
 
ext_labels = ['i', 'm', 'e', 'b', 'g']
teeth_labels = ['11','12','13','14','15','16','17','18',\
              '21','22','23','24','25','26','27','28',\
              '31','32','33','34','35','36','37','38',\
              '41','42','43','44','45','46','47','48']

# %%
def gen(img, lbl):
    allpoints = np.concatenate([np.array(shape['points']) for shape in lbl['shapes']])
    xmin, ymin = allpoints.min(axis=0)
    xmax, ymax = allpoints.max(axis=0)
    max_pad_x = (xmax - xmin)*0.07
    max_pad_y = (ymax - ymin)*0.07
    import random
    xmax += random.uniform(0, max_pad_x)
    xmin -= random.uniform(0, max_pad_x)
    ymax += random.uniform(0, max_pad_y)
    ymin -= random.uniform(0, max_pad_y)
 
    img_croped = img[int(ymin):int(ymax), int(xmin):int(xmax), :]
    img_croped = cv2.resize(img_croped, (512,256))
 
    ry = 256.0/(ymax-ymin)
    rx = 512.0/(xmax-xmin)
 
    masks = np.zeros(shape=(len(teeth_labels) + len(ext_labels),256,512), dtype=np.uint8)
    m = np.zeros(shape=(256,512), dtype=np.uint8)
 
    for shape in lbl['shapes']:
        c = Contour(shape['label'], shape['points'])
        i = teeth_labels.index(c.name[:2])
    #     mask = np.zeros(shape=(h,w))
        pts = c.xy_points
        pts -= [xmin,ymin]
        pts = (pts*[rx,ry]).astype(int)
        #print(pts)
        cv2.drawContours(masks[i], [pts], -1, 255, -1)
        m = cv2.add(m, masks[i]//255)
        if len(c.name) > 2:
            j = ext_labels.index(c.name[2])
            masks[len(teeth_labels) + j] = cv2.bitwise_or(masks[len(teeth_labels) + j], masks[i])
 
    labels_masks = np.rollaxis(masks, 0, 3)
    premask = np.stack([(m==0), (m==1), (m>1)], axis=2)
    return img_croped, premask, labels_masks > 0

# %%
# img_dir = '/home/loitg/ssd/data/dental_data/images/2007 387枚 読影済/'
# lbl_dir = '/home/loitg/ssd/data/dental_data/json/2007 387枚 読影済/'
# temp_dir = '/home/loitg/workspace/dental/temp'
 
# fn = '20070508105519'
# imgfn = fn + '.png'
# lblfn = fn + '.json'
# img = cv2.imread(os.path.join(img_dir, imgfn))
 
# lbl = json.load(open(os.path.join(lbl_dir, lblfn)))
 
# img_croped, premask, labels_masks = gen(img, lbl)

# %%
# np.concatenate([labels_masks, premask], axis=2).shape

# %%
from glob import glob
import random
 
temp_dir = '/content/gdrive/My Drive/workspace/dental/temp/'
root_data = '/content/gdrive/My Drive/workspace/dental/'
all_json = glob('/content/gdrive/My Drive/workspace/dental_data/json/*/*.json')
 
def kkk():
    random.shuffle(all_json)
    for path_json in all_json:
        try:
            path_png = path_json.replace('.json','.png').replace('json','images')
            img = cv2.imread(path_png)
            if len(img.shape) < 3 or img.shape[2] < 3:
                img = cv2.ctvColor(img, cv2.COLOR_GRAY2BGR)
            lbl = json.load(open(path_json))
            _, fn = os.path.split(path_png)
            # print(fn)
            img_croped, premask, labels_masks = gen(img, lbl)
            img_normalized = img_croped/128.0 - 1
            yield img_normalized, (premask, labels_masks)
        except Exception as e:
            print('Exception!!!')
            continue

# %%
import tensorflow as tf
train_ds = tf.data.Dataset.from_generator(kkk, args=[], output_types=(tf.float64,(tf.uint8,tf.uint8)) ,\
                                    output_shapes = ((256, 512, 3), ((256, 512, 3), (256, 512, 37)) ))
train_ds = train_ds.batch(4)

# %%
val_ds = train_ds.take(4)
val_ds = list(val_ds)
# Out:
# Exception!!!

# %%
len(val_ds)
# Out:
# 4

# %%
for a, b in train_ds:
    print(a.shape)
    print(len(b))
    break
# Out:
# (4, 256, 512, 3)
# 2

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers as KL
 
class SeqConv(KL.Layer):
    
    def __init__(self, y_step, rnn_unit=-1, name='', output_size=-1):
        super(SeqConv, self).__init__(name=name)
        self.y_step = y_step
        self.rnn_unit = rnn_unit
        self.output_size = output_size
    
    def build(self, input_shape):
        _, height, width, channel = input_shape
        if self.rnn_unit < 0:
            self.rnn_unit = channel
        self.rnn_x = KL.GRU(self.rnn_unit, return_sequences=True, name=self.name + '-rnnx', kernel_initializer = 'he_normal')
        self.rnn_x = KL.TimeDistributed(KL.Bidirectional(self.rnn_x), name=self.name + '-bidrnnx')
        
        #self.input_depth = channel
        a = self.y_step
        self.downx = KL.Conv2D(self.rnn_unit, (2*a+1, 2*a+1), strides=(a+1,1), padding='same', name=self.name +'-downx', kernel_initializer = 'he_normal')
        self.upx = KL.UpSampling2D((a+1,1), interpolation='bilinear', name=self.name+'-upx')
        if self.output_size < 0:
            self.output_size = channel
        self.up = KL.Conv2D(self.output_size, (1,1), name=self.name + '-up', kernel_initializer = 'he_normal')
                               
    def call(self, input_tensor):
        x = self.downx(input_tensor)
        x = self.rnn_x(x)
        x = self.upx(x)
        z = tf.concat([input_tensor, x], -1)
        z = self.up(z)
        return z
        
    def get_config(self):
        config = super(SeqConv, self).get_config()
        config.update({"rnn_x": self.rnn_x, "downx":self.downx, "upx":self.upx,\
                       "rnn_unit":self.rnn_unit, "y_step":self.y_step, "output_size":self.output_size,\
                      "up":self.up})
        return config
 
def identity_block(input_tensor, kernel_size, filters, stage, block,
                   use_bias=True, train_bn=True):
    """The identity_block is the block that has no conv layer at shortcut
    # Arguments
        input_tensor: input tensorimport keras.layers as KL
        kernel_size: default 3, the kernel size of middle conv layer at main path
        filters: list of integers, the nb_filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
        use_bias: Boolean. To use or not use a bias in conv layers.
        train_bn: Boolean. Train or freeze Batch Norm layers
    """
    nb_filter1, nb_filter2, nb_filter3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
 
    x = KL.Conv2D(nb_filter1, (1, 1), name=conv_name_base + '2a',
                  use_bias=use_bias, kernel_initializer = 'he_normal')(input_tensor)
    x = KL.BatchNormalization(name=bn_name_base + '2a')(x, training=train_bn)
    x = KL.Activation('relu')(x)
 
    x = KL.Conv2D(nb_filter2, (kernel_size, kernel_size), padding='same',
                  name=conv_name_base + '2b', use_bias=use_bias, kernel_initializer = 'he_normal')(x)
    x = KL.BatchNormalization(name=bn_name_base + '2b')(x, training=train_bn)
    x = KL.Activation('relu')(x)
 
    x = KL.Conv2D(nb_filter3, (1, 1), name=conv_name_base + '2c',
                  use_bias=use_bias, kernel_initializer = 'he_normal')(x)
    x = KL.BatchNormalization(name=bn_name_base + '2c')(x, training=train_bn)
 
    x = KL.Add()([x, input_tensor])
    x = KL.Activation('relu', name='res' + str(stage) + block + '_out')(x)
    return x
 
def conv_block(input_tensor, kernel_size, filters, stage, block,
               strides=(2, 2), use_bias=True, train_bn=True):
    """conv_block is the block that has a conv layer at shortcut
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of middle conv layer at main path
        filters: list of integers, the nb_filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
        use_bias: Boolean. To use or not use a bias in conv layers.
        train_bn: Boolean. Train or freeze Batch Norm layers
    Note that from stage 3, the first conv layer at main path is with subsample=(2,2)
    And the shortcut should have subsample=(2,2) as well
    """
    nb_filter1, nb_filter2, nb_filter3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
 
    x = KL.Conv2D(nb_filter1, (1, 1), strides=strides,
                  name=conv_name_base + '2a', use_bias=use_bias)(input_tensor)
    x = KL.BatchNormalization(name=bn_name_base + '2a')(x, training=train_bn)
    x = KL.Activation('relu')(x)
 
    x = KL.Conv2D(nb_filter2, (kernel_size, kernel_size), padding='same',
                  name=conv_name_base + '2b', use_bias=use_bias)(x)
    x = KL.BatchNormalization(name=bn_name_base + '2b')(x, training=train_bn)
    x = KL.Activation('relu')(x)
 
    x = KL.Conv2D(nb_filter3, (1, 1), name=conv_name_base +
                  '2c', use_bias=use_bias)(x)
    x = KL.BatchNormalization(name=bn_name_base + '2c')(x, training=train_bn)
 
    shortcut = KL.Conv2D(nb_filter3, (1, 1), strides=strides,
                         name=conv_name_base + '1', use_bias=use_bias)(input_tensor)
    shortcut = KL.BatchNormalization(name=bn_name_base + '1')(shortcut, training=train_bn)
 
    x = KL.Add()([x, shortcut])
    x = KL.Activation('relu', name='res' + str(stage) + block + '_out')(x)
    return x
 
 
def stage_shallow(input_tensor, filter_n, depth, stage, train_bn, insert_seqconv=False, rnn_unit=-1):
    x = KL.Conv2D(filter_n, (3,3), padding='same', name=stage+'-conv01', kernel_initializer = 'he_normal')(input_tensor)
    x = KL.BatchNormalization(name=stage + '-bn1')(x, training=train_bn)
    if insert_seqconv:
        x = SeqConv(y_step=1, rnn_unit=rnn_unit, output_size=-1, name=stage+'-seqconv-')(x)
        x = KL.BatchNormalization(name=stage + '-bnseqconv')(x, training=train_bn)
    x = KL.Conv2D(filter_n, (3,3), padding='same', name=stage+'conv11', kernel_initializer = 'he_normal')(x)
    x = KL.BatchNormalization(name=stage + '-bn2')(x, training=train_bn)
    return x
 
def stage_deep(input_tensor, filter_n, depth, stage, train_bn, insert_seqconv=False, rnn_unit=-1):
    filters = [filter_n//2, filter_n//2, filter_n]
    if insert_seqconv:
        x = SeqConv(y_step=1, rnn_unit=rnn_unit, output_size=filter_n, name=stage + '-seqconv-')(input_tensor)
        x = KL.BatchNormalization(name=stage + '-bn')(x, training=train_bn)
    else:
        x = conv_block(input_tensor, 3, filters, stage=stage, block='conv', strides=(1,1), train_bn=train_bn)
    for i in range(depth):
        x = identity_block(x, 3, filters, stage=stage, block='i' + str(i), train_bn=train_bn)
    return x
 
def head_graph(features, filters, name):
    x = features
    for i, filter_ in enumerate(filters):
        x = KL.Conv2D(filter_, (1, 1), padding="SAME", name=name+str(i))(x)
        x = KL.BatchNormalization(name=name+'bn'+str(i))(x)
    return x
 
 
def unet(input_image, name='', train_bn=False): #256x512
    depth = None
    
    C1 = stage_shallow(input_image, 64, depth, name+'C1', train_bn, insert_seqconv=False)
    C2 = KL.MaxPooling2D(pool_size=(2, 2))(C1) #128x256 (/2)
    C2 = stage_shallow(C2, 128, depth, name+'C2', train_bn, insert_seqconv=False)
    C3 = KL.MaxPooling2D(pool_size=(2, 2))(C2) #64x128 (/4)
    C3 = stage_deep(C3, 256, 5, name+'C3', train_bn, insert_seqconv=False)
    C4 = KL.MaxPooling2D(pool_size=(2, 2))(C3) #32x64 (/8)
    C4 = stage_deep(C4, 256, 10, name+'C4', train_bn, insert_seqconv=True, rnn_unit=32)
    C5 = KL.MaxPooling2D(pool_size=(2, 2))(C4) #16x32 (/16)
    C5 = stage_deep(C5, 512, 20, name+'C5', train_bn, insert_seqconv=True, rnn_unit=128)
    C6 = KL.MaxPooling2D(pool_size=(2, 2))(C5) #8x16 (/32)
    
    P6 = stage_shallow(C6, 512, depth, name+'C6P6', train_bn, insert_seqconv=False) #8x16
    P5 = KL.Concatenate(name=name+'concatP6C5')([KL.UpSampling2D(size=(2, 2))(P6), C5]) #16x32
    P5 = stage_shallow(P5, 512, 20, name+'P5', train_bn, insert_seqconv=True, rnn_unit=128)
 
    P4 = KL.Concatenate(name=name+'concatP5C4')([KL.UpSampling2D(size=(2, 2))(P5), C4]) #32x64
    P4 = stage_shallow(P4, 512, 10, name+'P4', train_bn, insert_seqconv=True, rnn_unit=32)
 
    P3 = KL.Concatenate(name=name+'concatP4C3')([KL.UpSampling2D(size=(2, 2))(P4), C3]) #64x128
    P3 = stage_shallow(P3, 256, 5, name+'P3', train_bn, insert_seqconv=False)
 
    P2 = KL.Concatenate(name=name+'concatP3C2')([KL.UpSampling2D(size=(2, 2))(P3), C2]) #256
    P2 = stage_shallow(P2, 256, depth, name+'P2', train_bn, insert_seqconv=False)
    
    P1 = KL.Concatenate(name=name+'concatP2C1')([KL.UpSampling2D(size=(2, 2))(P2), C1]) #512
    P1 = stage_shallow(P1, 128, depth, name+'P1', train_bn, insert_seqconv=False)
    
    return P1

# %%
from tensorflow.keras import Input, Model
 
tf.keras.backend.clear_session()
 
input_size=(256,512)
image = Input(input_size + (3,))
features1 = unet(image, name='USC-', train_bn=True)
premask_output_1 = head_graph(features1, filters=[32,3], name='premask_branch_1')
labels_output_1 = head_graph(features1, filters=[64,37], name='labels_branch_1')
 
model = Model([image], outputs=[premask_output_1, labels_output_1])
model.compile(optimizer = tf.keras.optimizers.Adam(lr = 1e-4), loss=[tf.keras.losses.CategoricalCrossentropy(from_logits=True),\
                                                                     tf.keras.losses.BinaryCrossentropy(from_logits=True)])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 512, 3) 0
# __________________________________________________________________________________________________
# USC-C1-conv01 (Conv2D)          (None, 256, 512, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# USC-C1-bn1 (BatchNormalization) (None, 256, 512, 64) 256         USC-C1-conv01[0][0]
# __________________________________________________________________________________________________
# USC-C1conv11 (Conv2D)           (None, 256, 512, 64) 36928       USC-C1-bn1[0][0]
# __________________________________________________________________________________________________
# USC-C1-bn2 (BatchNormalization) (None, 256, 512, 64) 256         USC-C1conv11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 256, 64) 0           USC-C1-bn2[0][0]
# __________________________________________________________________________________________________
# USC-C2-conv01 (Conv2D)          (None, 128, 256, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# USC-C2-bn1 (BatchNormalization) (None, 128, 256, 128 512         USC-C2-conv01[0][0]
# __________________________________________________________________________________________________
# USC-C2conv11 (Conv2D)           (None, 128, 256, 128 147584      USC-C2-bn1[0][0]
# __________________________________________________________________________________________________
# USC-C2-bn2 (BatchNormalization) (None, 128, 256, 128 512         USC-C2conv11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 128, 128) 0           USC-C2-bn2[0][0]
# __________________________________________________________________________________________________
# resUSC-C3conv_branch2a (Conv2D) (None, 64, 128, 128) 16512       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3conv_branch2a (BatchNor (None, 64, 128, 128) 512         resUSC-C3conv_branch2a[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 128, 128) 0           bnUSC-C3conv_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C3conv_branch2b (Conv2D) (None, 64, 128, 128) 147584      activation[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3conv_branch2b (BatchNor (None, 64, 128, 128) 512         resUSC-C3conv_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3conv_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C3conv_branch2c (Conv2D) (None, 64, 128, 256) 33024       activation_1[0][0]
# __________________________________________________________________________________________________
# resUSC-C3conv_branch1 (Conv2D)  (None, 64, 128, 256) 33024       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3conv_branch2c (BatchNor (None, 64, 128, 256) 1024        resUSC-C3conv_branch2c[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3conv_branch1 (BatchNorm (None, 64, 128, 256) 1024        resUSC-C3conv_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 128, 256) 0           bnUSC-C3conv_branch2c[0][0]
#                                                                  bnUSC-C3conv_branch1[0][0]
# __________________________________________________________________________________________________
# resUSC-C3conv_out (Activation)  (None, 64, 128, 256) 0           add[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i0_branch2a (Conv2D)   (None, 64, 128, 128) 32896       resUSC-C3conv_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i0_branch2a (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i0_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i0_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i0_branch2b (Conv2D)   (None, 64, 128, 128) 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i0_branch2b (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i0_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i0_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i0_branch2c (Conv2D)   (None, 64, 128, 256) 33024       activation_3[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i0_branch2c (BatchNorma (None, 64, 128, 256) 1024        resUSC-C3i0_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 128, 256) 0           bnUSC-C3i0_branch2c[0][0]
#                                                                  resUSC-C3conv_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i0_out (Activation)    (None, 64, 128, 256) 0           add_1[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i1_branch2a (Conv2D)   (None, 64, 128, 128) 32896       resUSC-C3i0_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i1_branch2a (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i1_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i1_branch2b (Conv2D)   (None, 64, 128, 128) 147584      activation_4[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i1_branch2b (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i1_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i1_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i1_branch2c (Conv2D)   (None, 64, 128, 256) 33024       activation_5[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i1_branch2c (BatchNorma (None, 64, 128, 256) 1024        resUSC-C3i1_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 128, 256) 0           bnUSC-C3i1_branch2c[0][0]
#                                                                  resUSC-C3i0_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i1_out (Activation)    (None, 64, 128, 256) 0           add_2[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i2_branch2a (Conv2D)   (None, 64, 128, 128) 32896       resUSC-C3i1_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i2_branch2a (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i2_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i2_branch2b (Conv2D)   (None, 64, 128, 128) 147584      activation_6[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i2_branch2b (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i2_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i2_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i2_branch2c (Conv2D)   (None, 64, 128, 256) 33024       activation_7[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i2_branch2c (BatchNorma (None, 64, 128, 256) 1024        resUSC-C3i2_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 128, 256) 0           bnUSC-C3i2_branch2c[0][0]
#                                                                  resUSC-C3i1_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i2_out (Activation)    (None, 64, 128, 256) 0           add_3[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i3_branch2a (Conv2D)   (None, 64, 128, 128) 32896       resUSC-C3i2_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i3_branch2a (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i3_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i3_branch2b (Conv2D)   (None, 64, 128, 128) 147584      activation_8[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i3_branch2b (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i3_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 128, 128) 0           bnUSC-C3i3_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i3_branch2c (Conv2D)   (None, 64, 128, 256) 33024       activation_9[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i3_branch2c (BatchNorma (None, 64, 128, 256) 1024        resUSC-C3i3_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 128, 256) 0           bnUSC-C3i3_branch2c[0][0]
#                                                                  resUSC-C3i2_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i3_out (Activation)    (None, 64, 128, 256) 0           add_4[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i4_branch2a (Conv2D)   (None, 64, 128, 128) 32896       resUSC-C3i3_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i4_branch2a (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 128, 128) 0           bnUSC-C3i4_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i4_branch2b (Conv2D)   (None, 64, 128, 128) 147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i4_branch2b (BatchNorma (None, 64, 128, 128) 512         resUSC-C3i4_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 128, 128) 0           bnUSC-C3i4_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i4_branch2c (Conv2D)   (None, 64, 128, 256) 33024       activation_11[0][0]
# __________________________________________________________________________________________________
# bnUSC-C3i4_branch2c (BatchNorma (None, 64, 128, 256) 1024        resUSC-C3i4_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 128, 256) 0           bnUSC-C3i4_branch2c[0][0]
#                                                                  resUSC-C3i3_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C3i4_out (Activation)    (None, 64, 128, 256) 0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 64, 256)  0           resUSC-C3i4_out[0][0]
# __________________________________________________________________________________________________
# USC-C4-seqconv- (SeqConv)       (None, 32, 64, 256)  168608      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# USC-C4-bn (BatchNormalization)  (None, 32, 64, 256)  1024        USC-C4-seqconv-[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i0_branch2a (Conv2D)   (None, 32, 64, 128)  32896       USC-C4-bn[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i0_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i0_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i0_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i0_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i0_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i0_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i0_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i0_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_13[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i0_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i0_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 64, 256)  0           bnUSC-C4i0_branch2c[0][0]
#                                                                  USC-C4-bn[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i0_out (Activation)    (None, 32, 64, 256)  0           add_6[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i1_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i0_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i1_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i1_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i1_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i1_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i1_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i1_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i1_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_15[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i1_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i1_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 64, 256)  0           bnUSC-C4i1_branch2c[0][0]
#                                                                  resUSC-C4i0_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i1_out (Activation)    (None, 32, 64, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i2_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i1_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i2_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i2_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i2_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i2_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i2_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i2_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i2_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_17[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i2_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i2_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 64, 256)  0           bnUSC-C4i2_branch2c[0][0]
#                                                                  resUSC-C4i1_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i2_out (Activation)    (None, 32, 64, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i3_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i2_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i3_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i3_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i3_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i3_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i3_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i3_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i3_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_19[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i3_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i3_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 64, 256)  0           bnUSC-C4i3_branch2c[0][0]
#                                                                  resUSC-C4i2_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i3_out (Activation)    (None, 32, 64, 256)  0           add_9[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i4_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i3_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i4_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i4_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i4_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i4_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i4_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i4_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i4_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_21[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i4_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i4_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 64, 256)  0           bnUSC-C4i4_branch2c[0][0]
#                                                                  resUSC-C4i3_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i4_out (Activation)    (None, 32, 64, 256)  0           add_10[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i5_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i4_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i5_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i5_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i5_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i5_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_22[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i5_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i5_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i5_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i5_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_23[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i5_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i5_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 64, 256)  0           bnUSC-C4i5_branch2c[0][0]
#                                                                  resUSC-C4i4_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i5_out (Activation)    (None, 32, 64, 256)  0           add_11[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i6_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i5_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i6_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i6_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i6_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i6_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_24[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i6_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i6_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i6_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i6_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_25[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i6_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i6_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 64, 256)  0           bnUSC-C4i6_branch2c[0][0]
#                                                                  resUSC-C4i5_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i6_out (Activation)    (None, 32, 64, 256)  0           add_12[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i7_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i6_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i7_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i7_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i7_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i7_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i7_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i7_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i7_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i7_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_27[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i7_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i7_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 64, 256)  0           bnUSC-C4i7_branch2c[0][0]
#                                                                  resUSC-C4i6_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i7_out (Activation)    (None, 32, 64, 256)  0           add_13[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i8_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i7_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i8_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i8_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i8_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i8_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i8_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i8_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i8_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i8_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_29[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i8_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i8_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 64, 256)  0           bnUSC-C4i8_branch2c[0][0]
#                                                                  resUSC-C4i7_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i8_out (Activation)    (None, 32, 64, 256)  0           add_14[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i9_branch2a (Conv2D)   (None, 32, 64, 128)  32896       resUSC-C4i8_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i9_branch2a (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i9_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i9_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i9_branch2b (Conv2D)   (None, 32, 64, 128)  147584      activation_30[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i9_branch2b (BatchNorma (None, 32, 64, 128)  512         resUSC-C4i9_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 64, 128)  0           bnUSC-C4i9_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i9_branch2c (Conv2D)   (None, 32, 64, 256)  33024       activation_31[0][0]
# __________________________________________________________________________________________________
# bnUSC-C4i9_branch2c (BatchNorma (None, 32, 64, 256)  1024        resUSC-C4i9_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 64, 256)  0           bnUSC-C4i9_branch2c[0][0]
#                                                                  resUSC-C4i8_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C4i9_out (Activation)    (None, 32, 64, 256)  0           add_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 32, 256)  0           resUSC-C4i9_out[0][0]
# __________________________________________________________________________________________________
# USC-C5-seqconv- (SeqConv)       (None, 16, 32, 512)  755840      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# USC-C5-bn (BatchNormalization)  (None, 16, 32, 512)  2048        USC-C5-seqconv-[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i0_branch2a (Conv2D)   (None, 16, 32, 256)  131328      USC-C5-bn[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i0_branch2a (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i0_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i0_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i0_branch2b (Conv2D)   (None, 16, 32, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i0_branch2b (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i0_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i0_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i0_branch2c (Conv2D)   (None, 16, 32, 512)  131584      activation_33[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i0_branch2c (BatchNorma (None, 16, 32, 512)  2048        resUSC-C5i0_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i0_branch2c[0][0]
#                                                                  USC-C5-bn[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i0_out (Activation)    (None, 16, 32, 512)  0           add_16[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i1_branch2a (Conv2D)   (None, 16, 32, 256)  131328      resUSC-C5i0_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i1_branch2a (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i1_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i1_branch2b (Conv2D)   (None, 16, 32, 256)  590080      activation_34[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i1_branch2b (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i1_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i1_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i1_branch2c (Conv2D)   (None, 16, 32, 512)  131584      activation_35[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i1_branch2c (BatchNorma (None, 16, 32, 512)  2048        resUSC-C5i1_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i1_branch2c[0][0]
#                                                                  resUSC-C5i0_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i1_out (Activation)    (None, 16, 32, 512)  0           add_17[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i2_branch2a (Conv2D)   (None, 16, 32, 256)  131328      resUSC-C5i1_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i2_branch2a (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i2_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i2_branch2b (Conv2D)   (None, 16, 32, 256)  590080      activation_36[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i2_branch2b (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i2_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i2_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i2_branch2c (Conv2D)   (None, 16, 32, 512)  131584      activation_37[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i2_branch2c (BatchNorma (None, 16, 32, 512)  2048        resUSC-C5i2_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i2_branch2c[0][0]
#                                                                  resUSC-C5i1_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i2_out (Activation)    (None, 16, 32, 512)  0           add_18[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i3_branch2a (Conv2D)   (None, 16, 32, 256)  131328      resUSC-C5i2_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i3_branch2a (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i3_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i3_branch2b (Conv2D)   (None, 16, 32, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i3_branch2b (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i3_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i3_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i3_branch2c (Conv2D)   (None, 16, 32, 512)  131584      activation_39[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i3_branch2c (BatchNorma (None, 16, 32, 512)  2048        resUSC-C5i3_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i3_branch2c[0][0]
#                                                                  resUSC-C5i2_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i3_out (Activation)    (None, 16, 32, 512)  0           add_19[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i4_branch2a (Conv2D)   (None, 16, 32, 256)  131328      resUSC-C5i3_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i4_branch2a (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i4_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i4_branch2b (Conv2D)   (None, 16, 32, 256)  590080      activation_40[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i4_branch2b (BatchNorma (None, 16, 32, 256)  1024        resUSC-C5i4_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i4_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i4_branch2c (Conv2D)   (None, 16, 32, 512)  131584      activation_41[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i4_branch2c (BatchNorma (None, 16, 32, 512)  2048        resUSC-C5i4_branch2c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i4_branch2c[0][0]
#                                                                  resUSC-C5i3_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i4_out (Activation)    (None, 16, 32, 512)  0           add_20[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i5_branch2a (Conv2D)   (None, 16, 32, 256)  131328      resUSC-C5i4_out[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i17_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i17_branch2b (Conv2D)  (None, 16, 32, 256)  590080      activation_66[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i17_branch2b (BatchNorm (None, 16, 32, 256)  1024        resUSC-C5i17_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i17_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i17_branch2c (Conv2D)  (None, 16, 32, 512)  131584      activation_67[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i17_branch2c (BatchNorm (None, 16, 32, 512)  2048        resUSC-C5i17_branch2c[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i17_branch2c[0][0]
#                                                                  resUSC-C5i16_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i17_out (Activation)   (None, 16, 32, 512)  0           add_33[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i18_branch2a (Conv2D)  (None, 16, 32, 256)  131328      resUSC-C5i17_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i18_branch2a (BatchNorm (None, 16, 32, 256)  1024        resUSC-C5i18_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i18_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i18_branch2b (Conv2D)  (None, 16, 32, 256)  590080      activation_68[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i18_branch2b (BatchNorm (None, 16, 32, 256)  1024        resUSC-C5i18_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i18_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i18_branch2c (Conv2D)  (None, 16, 32, 512)  131584      activation_69[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i18_branch2c (BatchNorm (None, 16, 32, 512)  2048        resUSC-C5i18_branch2c[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i18_branch2c[0][0]
#                                                                  resUSC-C5i17_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i18_out (Activation)   (None, 16, 32, 512)  0           add_34[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i19_branch2a (Conv2D)  (None, 16, 32, 256)  131328      resUSC-C5i18_out[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i19_branch2a (BatchNorm (None, 16, 32, 256)  1024        resUSC-C5i19_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i19_branch2a[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i19_branch2b (Conv2D)  (None, 16, 32, 256)  590080      activation_70[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i19_branch2b (BatchNorm (None, 16, 32, 256)  1024        resUSC-C5i19_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 16, 32, 256)  0           bnUSC-C5i19_branch2b[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i19_branch2c (Conv2D)  (None, 16, 32, 512)  131584      activation_71[0][0]
# __________________________________________________________________________________________________
# bnUSC-C5i19_branch2c (BatchNorm (None, 16, 32, 512)  2048        resUSC-C5i19_branch2c[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 16, 32, 512)  0           bnUSC-C5i19_branch2c[0][0]
#                                                                  resUSC-C5i18_out[0][0]
# __________________________________________________________________________________________________
# resUSC-C5i19_out (Activation)   (None, 16, 32, 512)  0           add_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 16, 512)   0           resUSC-C5i19_out[0][0]
# __________________________________________________________________________________________________
# USC-C6P6-conv01 (Conv2D)        (None, 8, 16, 512)   2359808     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# USC-C6P6-bn1 (BatchNormalizatio (None, 8, 16, 512)   2048        USC-C6P6-conv01[0][0]
# __________________________________________________________________________________________________
# USC-C6P6conv11 (Conv2D)         (None, 8, 16, 512)   2359808     USC-C6P6-bn1[0][0]
# __________________________________________________________________________________________________
# USC-C6P6-bn2 (BatchNormalizatio (None, 8, 16, 512)   2048        USC-C6P6conv11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 32, 512)  0           USC-C6P6-bn2[0][0]
# __________________________________________________________________________________________________
# USC-concatP6C5 (Concatenate)    (None, 16, 32, 1024) 0           up_sampling2d[0][0]
#                                                                  resUSC-C5i19_out[0][0]
# __________________________________________________________________________________________________
# USC-P5-conv01 (Conv2D)          (None, 16, 32, 512)  4719104     USC-concatP6C5[0][0]
# __________________________________________________________________________________________________
# USC-P5-bn1 (BatchNormalization) (None, 16, 32, 512)  2048        USC-P5-conv01[0][0]
# __________________________________________________________________________________________________
# USC-P5-seqconv- (SeqConv)       (None, 16, 32, 512)  1181824     USC-P5-bn1[0][0]
# __________________________________________________________________________________________________
# USC-P5-bnseqconv (BatchNormaliz (None, 16, 32, 512)  2048        USC-P5-seqconv-[0][0]
# __________________________________________________________________________________________________
# USC-P5conv11 (Conv2D)           (None, 16, 32, 512)  2359808     USC-P5-bnseqconv[0][0]
# __________________________________________________________________________________________________
# USC-P5-bn2 (BatchNormalization) (None, 16, 32, 512)  2048        USC-P5conv11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 64, 512)  0           USC-P5-bn2[0][0]
# __________________________________________________________________________________________________
# USC-concatP5C4 (Concatenate)    (None, 32, 64, 768)  0           up_sampling2d_1[0][0]
#                                                                  resUSC-C4i9_out[0][0]
# __________________________________________________________________________________________________
# USC-P4-conv01 (Conv2D)          (None, 32, 64, 512)  3539456     USC-concatP5C4[0][0]
# __________________________________________________________________________________________________
# USC-P4-bn1 (BatchNormalization) (None, 32, 64, 512)  2048        USC-P4-conv01[0][0]
# __________________________________________________________________________________________________
# USC-P4-seqconv- (SeqConv)       (None, 32, 64, 512)  455584      USC-P4-bn1[0][0]
# __________________________________________________________________________________________________
# USC-P4-bnseqconv (BatchNormaliz (None, 32, 64, 512)  2048        USC-P4-seqconv-[0][0]
# __________________________________________________________________________________________________
# USC-P4conv11 (Conv2D)           (None, 32, 64, 512)  2359808     USC-P4-bnseqconv[0][0]
# __________________________________________________________________________________________________
# USC-P4-bn2 (BatchNormalization) (None, 32, 64, 512)  2048        USC-P4conv11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 128, 512) 0           USC-P4-bn2[0][0]
# __________________________________________________________________________________________________
# USC-concatP4C3 (Concatenate)    (None, 64, 128, 768) 0           up_sampling2d_2[0][0]
#                                                                  resUSC-C3i4_out[0][0]
# __________________________________________________________________________________________________
# USC-P3-conv01 (Conv2D)          (None, 64, 128, 256) 1769728     USC-concatP4C3[0][0]
# __________________________________________________________________________________________________
# USC-P3-bn1 (BatchNormalization) (None, 64, 128, 256) 1024        USC-P3-conv01[0][0]
# __________________________________________________________________________________________________
# USC-P3conv11 (Conv2D)           (None, 64, 128, 256) 590080      USC-P3-bn1[0][0]
# __________________________________________________________________________________________________
# USC-P3-bn2 (BatchNormalization) (None, 64, 128, 256) 1024        USC-P3conv11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 256, 256 0           USC-P3-bn2[0][0]
# __________________________________________________________________________________________________
# USC-concatP3C2 (Concatenate)    (None, 128, 256, 384 0           up_sampling2d_3[0][0]
#                                                                  USC-C2-bn2[0][0]
# __________________________________________________________________________________________________
# USC-P2-conv01 (Conv2D)          (None, 128, 256, 256 884992      USC-concatP3C2[0][0]
# __________________________________________________________________________________________________
# USC-P2-bn1 (BatchNormalization) (None, 128, 256, 256 1024        USC-P2-conv01[0][0]
# __________________________________________________________________________________________________
# USC-P2conv11 (Conv2D)           (None, 128, 256, 256 590080      USC-P2-bn1[0][0]
# __________________________________________________________________________________________________
# USC-P2-bn2 (BatchNormalization) (None, 128, 256, 256 1024        USC-P2conv11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 256, 512, 256 0           USC-P2-bn2[0][0]
# __________________________________________________________________________________________________
# USC-concatP2C1 (Concatenate)    (None, 256, 512, 320 0           up_sampling2d_4[0][0]
#                                                                  USC-C1-bn2[0][0]
# __________________________________________________________________________________________________
# USC-P1-conv01 (Conv2D)          (None, 256, 512, 128 368768      USC-concatP2C1[0][0]
# __________________________________________________________________________________________________
# USC-P1-bn1 (BatchNormalization) (None, 256, 512, 128 512         USC-P1-conv01[0][0]
# __________________________________________________________________________________________________
# USC-P1conv11 (Conv2D)           (None, 256, 512, 128 147584      USC-P1-bn1[0][0]
# __________________________________________________________________________________________________
# USC-P1-bn2 (BatchNormalization) (None, 256, 512, 128 512         USC-P1conv11[0][0]
# __________________________________________________________________________________________________
# premask_branch_10 (Conv2D)      (None, 256, 512, 32) 4128        USC-P1-bn2[0][0]
# __________________________________________________________________________________________________
# labels_branch_10 (Conv2D)       (None, 256, 512, 64) 8256        USC-P1-bn2[0][0]
# __________________________________________________________________________________________________
# premask_branch_1bn0 (BatchNorma (None, 256, 512, 32) 128         premask_branch_10[0][0]
# __________________________________________________________________________________________________
# labels_branch_1bn0 (BatchNormal (None, 256, 512, 64) 256         labels_branch_10[0][0]
# __________________________________________________________________________________________________
# premask_branch_11 (Conv2D)      (None, 256, 512, 3)  99          premask_branch_1bn0[0][0]
# __________________________________________________________________________________________________
# labels_branch_11 (Conv2D)       (None, 256, 512, 37) 2405        labels_branch_1bn0[0][0]
# __________________________________________________________________________________________________
# premask_branch_1bn1 (BatchNorma (None, 256, 512, 3)  12          premask_branch_11[0][0]
# __________________________________________________________________________________________________
# labels_branch_1bn1 (BatchNormal (None, 256, 512, 37) 148         labels_branch_11[0][0]
# ==================================================================================================
# Total params: 45,520,840
# Trainable params: 45,449,656
# Non-trainable params: 71,184
# __________________________________________________________________________________________________

# %%
# model.load_weights('/content/gdrive/My Drive/workspace/dental/checkpoints/model.16.h5')
my_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath='/content/gdrive/My Drive/workspace/dental/checkpoints2/model.{epoch:02d}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='/content/gdrive/My Drive/workspace/dental/tb2/'),
]
 
history = model.fit(train_ds, epochs=100,initial_epoch=0, validation_data=val_ds, callbacks=my_callbacks, verbose=1)
# Out:
# Epoch 1/100
#       1/Unknown - 0s 667us/step - loss: 2.2023 - premask_branch_1bn1_loss: 1.4092 - labels_branch_1bn1_loss: 0.7930WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#      31/Unknown - 255s 8s/step - loss: 1.5939 - premask_branch_1bn1_loss: 0.8059 - labels_branch_1bn1_loss: 0.7880Exception!!!
#      49/Unknown - 407s 8s/step - loss: 1.5507 - premask_branch_1bn1_loss: 0.7676 - labels_branch_1bn1_loss: 0.7830Exception!!!
#      66/Unknown - 542s 8s/step - loss: 1.5224 - premask_branch_1bn1_loss: 0.7440 - labels_branch_1bn1_loss: 0.7784Exception!!!
#      79/Unknown - 642s 8s/step - loss: 1.5063 - premask_branch_1bn1_loss: 0.7313 - labels_branch_1bn1_loss: 0.7751Exception!!!
#      92/Unknown - 747s 8s/step - loss: 1.4945 - premask_branch_1bn1_loss: 0.7224 - labels_branch_1bn1_loss: 0.7722Exception!!!
#      93/Unknown - 758s 8s/step - loss: 1.4937 - premask_branch_1bn1_loss: 0.7217 - labels_branch_1bn1_loss: 0.7720Exception!!!
#     110/Unknown - 889s 8s/step - loss: 1.4831 - premask_branch_1bn1_loss: 0.7145 - labels_branch_1bn1_loss: 0.7686Exception!!!
#     136/Unknown - 1090s 8s/step - loss: 1.4674 - premask_branch_1bn1_loss: 0.7036 - labels_branch_1bn1_loss: 0.7638Exception!!!
#     140/Unknown - 1122s 8s/step - loss: 1.4649 - premask_branch_1bn1_loss: 0.7018 - labels_branch_1bn1_loss: 0.7631Exception!!!
#     143/Unknown - 1150s 8s/step - loss: 1.4632 - premask_branch_1bn1_loss: 0.7006 - labels_branch_1bn1_loss: 0.7626Exception!!!
#     144/Unknown - 1159s 8s/step - loss: 1.4626 - premask_branch_1bn1_loss: 0.7001 - labels_branch_1bn1_loss: 0.7625Exception!!!
#     150/Unknown - 1212s 8s/step - loss: 1.4599 - premask_branch_1bn1_loss: 0.6985 - labels_branch_1bn1_loss: 0.7614Exception!!!
#     177/Unknown - 1423s 8s/step - loss: 1.4481 - premask_branch_1bn1_loss: 0.6907 - labels_branch_1bn1_loss: 0.7575Exception!!!
#     183/Unknown - 1467s 8s/step - loss: 1.4459 - premask_branch_1bn1_loss: 0.6893 - labels_branch_1bn1_loss: 0.7566Exception!!!
#     184/Unknown - 1477s 8s/step - loss: 1.4454 - premask_branch_1bn1_loss: 0.6890 - labels_branch_1bn1_loss: 0.7564Exception!!!
#     205/Unknown - 1649s 8s/step - loss: 1.4370 - premask_branch_1bn1_loss: 0.6833 - labels_branch_1bn1_loss: 0.7537Exception!!!
#     210/Unknown - 1683s 8s/step - loss: 1.4352 - premask_branch_1bn1_loss: 0.6822 - labels_branch_1bn1_loss: 0.7530Exception!!!
#     212/Unknown - 1697s 8s/step - loss: 1.4346 - premask_branch_1bn1_loss: 0.6818 - labels_branch_1bn1_loss: 0.7528Exception!!!
#     215/Unknown - 1719s 8s/step - loss: 1.4335 - premask_branch_1bn1_loss: 0.6811 - labels_branch_1bn1_loss: 0.7524Exception!!!
# Exception!!!
#     228/Unknown - 1817s 8s/step - loss: 1.4288 - premask_branch_1bn1_loss: 0.6779 - labels_branch_1bn1_loss: 0.7509Exception!!!
#     230/Unknown - 1832s 8s/step - loss: 1.4283 - premask_branch_1bn1_loss: 0.6777 - labels_branch_1bn1_loss: 0.7506Exception!!!
#     243/Unknown - 1933s 8s/step - loss: 1.4240 - premask_branch_1bn1_loss: 0.6749 - labels_branch_1bn1_loss: 0.7492Exception!!!
#     292/Unknown - 2311s 8s/step - loss: 1.4090 - premask_branch_1bn1_loss: 0.6649 - labels_branch_1bn1_loss: 0.7441Exception!!!
#     299/Unknown - 2366s 8s/step - loss: 1.4072 - premask_branch_1bn1_loss: 0.6637 - labels_branch_1bn1_loss: 0.7435Exception!!!
#     300/Unknown - 2377s 8s/step - loss: 1.4069 - premask_branch_1bn1_loss: 0.6635 - labels_branch_1bn1_loss: 0.7434Exception!!!
#     313/Unknown - 2473s 8s/step - loss: 1.4033 - premask_branch_1bn1_loss: 0.6611 - labels_branch_1bn1_loss: 0.7422Exception!!!
#     329/Unknown - 2606s 8s/step - loss: 1.3995 - premask_branch_1bn1_loss: 0.6586 - labels_branch_1bn1_loss: 0.7409Exception!!!
#     339/Unknown - 2697s 8s/step - loss: 1.3972 - premask_branch_1bn1_loss: 0.6571 - labels_branch_1bn1_loss: 0.7401Exception!!!
#     355/Unknown - 2819s 8s/step - loss: 1.3935 - premask_branch_1bn1_loss: 0.6547 - labels_branch_1bn1_loss: 0.7388Exception!!!
#     364/Unknown - 2885s 8s/step - loss: 1.3915 - premask_branch_1bn1_loss: 0.6533 - labels_branch_1bn1_loss: 0.7382Exception!!!
#     370/Unknown - 2931s 8s/step - loss: 1.3903 - premask_branch_1bn1_loss: 0.6525 - labels_branch_1bn1_loss: 0.7378Exception!!!
#     371/Unknown - 2940s 8s/step - loss: 1.3901 - premask_branch_1bn1_loss: 0.6524 - labels_branch_1bn1_loss: 0.7377Exception!!!
#     375/Unknown - 2972s 8s/step - loss: 1.3891 - premask_branch_1bn1_loss: 0.6517 - labels_branch_1bn1_loss: 0.7374Exception!!!
#     397/Unknown - 3145s 8s/step - loss: 1.3840 - premask_branch_1bn1_loss: 0.6483 - labels_branch_1bn1_loss: 0.7358Exception!!!
#     400/Unknown - 3166s 8s/step - loss: 1.3834 - premask_branch_1bn1_loss: 0.6479 - labels_branch_1bn1_loss: 0.7355Exception!!!
#     403/Unknown - 3190s 8s/step - loss: 1.3828 - premask_branch_1bn1_loss: 0.6475 - labels_branch_1bn1_loss: 0.7353Exception!!!
#     413/Unknown - 3264s 8s/step - loss: 1.3808 - premask_branch_1bn1_loss: 0.6462 - labels_branch_1bn1_loss: 0.7346Exception!!!
#     424/Unknown - 3343s 8s/step - loss: 1.3784 - premask_branch_1bn1_loss: 0.6445 - labels_branch_1bn1_loss: 0.7339Exception!!!
#     447/Unknown - 3525s 8s/step - loss: 1.3738 - premask_branch_1bn1_loss: 0.6414 - labels_branch_1bn1_loss: 0.7324Exception!!!
#     452/Unknown - 3565s 8s/step - loss: 1.3727 - premask_branch_1bn1_loss: 0.6406 - labels_branch_1bn1_loss: 0.7321Exception!!!
#     464/Unknown - 3652s 8s/step - loss: 1.3702 - premask_branch_1bn1_loss: 0.6388 - labels_branch_1bn1_loss: 0.7314Exception!!!
#     471/Unknown - 3710s 8s/step - loss: 1.3687 - premask_branch_1bn1_loss: 0.6378 - labels_branch_1bn1_loss: 0.7309Exception!!!
#     504/Unknown - 3984s 8s/step - loss: 1.3623 - premask_branch_1bn1_loss: 0.6334 - labels_branch_1bn1_loss: 0.7289Exception!!!
#     508/Unknown - 4013s 8s/step - loss: 1.3617 - premask_branch_1bn1_loss: 0.6330 - labels_branch_1bn1_loss: 0.7286Exception!!!
#     517/Unknown - 4081s 8s/step - loss: 1.3600 - premask_branch_1bn1_loss: 0.6319 - labels_branch_1bn1_loss: 0.7281Exception!!!
#     521/Unknown - 4119s 8s/step - loss: 1.3594 - premask_branch_1bn1_loss: 0.6316 - labels_branch_1bn1_loss: 0.7279Exception!!!
#     532/Unknown - 4194s 8s/step - loss: 1.3573 - premask_branch_1bn1_loss: 0.6302 - labels_branch_1bn1_loss: 0.7271Exception!!!
#     534/Unknown - 4213s 8s/step - loss: 1.3569 - premask_branch_1bn1_loss: 0.6299 - labels_branch_1bn1_loss: 0.7270Exception!!!
#     585/Unknown - 4596s 8s/step - loss: 1.3482 - premask_branch_1bn1_loss: 0.6241 - labels_branch_1bn1_loss: 0.7241Exception!!!
#     587/Unknown - 4609s 8s/step - loss: 1.3479 - premask_branch_1bn1_loss: 0.6239 - labels_branch_1bn1_loss: 0.7240Exception!!!
#     588/Unknown - 4618s 8s/step - loss: 1.3477 - premask_branch_1bn1_loss: 0.6238 - labels_branch_1bn1_loss: 0.7239Exception!!!
#     589/Unknown - 4628s 8s/step - loss: 1.3475 - premask_branch_1bn1_loss: 0.6237 - labels_branch_1bn1_loss: 0.7239Exception!!!
#     649/Unknown - 5075s 8s/step - loss: 1.3375 - premask_branch_1bn1_loss: 0.6169 - labels_branch_1bn1_loss: 0.7206Exception!!!
#     655/Unknown - 5122s 8s/step - loss: 1.3365 - premask_branch_1bn1_loss: 0.6163 - labels_branch_1bn1_loss: 0.7203Exception!!!
#     668/Unknown - 5230s 8s/step - loss: 1.3343 - premask_branch_1bn1_loss: 0.6147 - labels_branch_1bn1_loss: 0.7196Exception!!!
#     684/Unknown - 5355s 8s/step - loss: 1.3316 - premask_branch_1bn1_loss: 0.6129 - labels_branch_1bn1_loss: 0.7187Exception!!!
#     686/Unknown - 5372s 8s/step - loss: 1.3313 - premask_branch_1bn1_loss: 0.6127 - labels_branch_1bn1_loss: 0.7186Exception!!!
#     698/Unknown - 5468s 8s/step - loss: 1.3294 - premask_branch_1bn1_loss: 0.6115 - labels_branch_1bn1_loss: 0.7179Exception!!!
#     699/Unknown - 5480s 8s/step - loss: 1.3292 - premask_branch_1bn1_loss: 0.6113 - labels_branch_1bn1_loss: 0.7179Exception!!!
#     706/Unknown - 5529s 8s/step - loss: 1.3281 - premask_branch_1bn1_loss: 0.6106 - labels_branch_1bn1_loss: 0.7175Exception!!!
#     707/Unknown - 5538s 8s/step - loss: 1.3279 - premask_branch_1bn1_loss: 0.6105 - labels_branch_1bn1_loss: 0.7174Exception!!!
#     745/Unknown - 5823s 8s/step - loss: 1.3220 - premask_branch_1bn1_loss: 0.6066 - labels_branch_1bn1_loss: 0.7154Exception!!!
#     753/Unknown - 5879s 8s/step - loss: 1.3207 - premask_branch_1bn1_loss: 0.6058 - labels_branch_1bn1_loss: 0.7150Exception!!!
#     775/Unknown - 6038s 8s/step - loss: 1.3173 - premask_branch_1bn1_loss: 0.6035 - labels_branch_1bn1_loss: 0.7138Exception!!!
#     778/Unknown - 6066s 8s/step - loss: 1.3168 - premask_branch_1bn1_loss: 0.6032 - labels_branch_1bn1_loss: 0.7136Exception!!!
#     819/Unknown - 6372s 8s/step - loss: 1.3109 - premask_branch_1bn1_loss: 0.5995 - labels_branch_1bn1_loss: 0.7115Exception!!!
#     822/Unknown - 6403s 8s/step - loss: 1.3105 - premask_branch_1bn1_loss: 0.5992 - labels_branch_1bn1_loss: 0.7113Exception!!!
#     839/Unknown - 6540s 8s/step - loss: 1.3080 - premask_branch_1bn1_loss: 0.5975 - labels_branch_1bn1_loss: 0.7105Exception!!!
#     841/Unknown - 6554s 8s/step - loss: 1.3077 - premask_branch_1bn1_loss: 0.5973 - labels_branch_1bn1_loss: 0.7104Exception!!!
# Exception!!!
#     846/Unknown - 6594s 8s/step - loss: 1.3069 - premask_branch_1bn1_loss: 0.5967 - labels_branch_1bn1_loss: 0.7101Exception!!!
#     850/Unknown - 6626s 8s/step - loss: 1.3064 - premask_branch_1bn1_loss: 0.5964 - labels_branch_1bn1_loss: 0.7099Exception!!!
#     870/Unknown - 6770s 8s/step - loss: 1.3034 - premask_branch_1bn1_loss: 0.5944 - labels_branch_1bn1_loss: 0.7090Exception!!!
#     887/Unknown - 6901s 8s/step - loss: 1.3010 - premask_branch_1bn1_loss: 0.5929 - labels_branch_1bn1_loss: 0.7082Exception!!!
#     899/Unknown - 6997s 8s/step - loss: 1.2993 - premask_branch_1bn1_loss: 0.5918 - labels_branch_1bn1_loss: 0.7076Exception!!!
#     915/Unknown - 7122s 8s/step - loss: 1.2970 - premask_branch_1bn1_loss: 0.5902 - labels_branch_1bn1_loss: 0.7068Exception!!!
# Exception!!!
#     916/Unknown - 7135s 8s/step - loss: 1.2968 - premask_branch_1bn1_loss: 0.5901 - labels_branch_1bn1_loss: 0.7067Exception!!!
#     921/Unknown - 7174s 8s/step - loss: 1.2962 - premask_branch_1bn1_loss: 0.5897 - labels_branch_1bn1_loss: 0.7065Exception!!!
#     961/Unknown - 7470s 8s/step - loss: 1.2907 - premask_branch_1bn1_loss: 0.5861 - labels_branch_1bn1_loss: 0.7046Exception!!!
# Exception!!!
#    1009/Unknown - 7922s 8s/step - loss: 1.2844 - premask_branch_1bn1_loss: 0.5820 - labels_branch_1bn1_loss: 0.7024Exception!!!
#    1017/Unknown - 7998s 8s/step - loss: 1.2833 - premask_branch_1bn1_loss: 0.5813 - labels_branch_1bn1_loss: 0.7020Exception!!!
#    1026/Unknown - 8083s 8s/step - loss: 1.2822 - premask_branch_1bn1_loss: 0.5805 - labels_branch_1bn1_loss: 0.7017Exception!!!
#    1033/Unknown - 8147s 8s/step - loss: 1.2813 - premask_branch_1bn1_loss: 0.5799 - labels_branch_1bn1_loss: 0.7014Exception!!!
#    1051/Unknown - 8315s 8s/step - loss: 1.2790 - premask_branch_1bn1_loss: 0.5784 - labels_branch_1bn1_loss: 0.7006Exception!!!
#    1068/Unknown - 8487s 8s/step - loss: 1.2768 - premask_branch_1bn1_loss: 0.5770 - labels_branch_1bn1_loss: 0.6999Exception!!!
#    1076/Unknown - 8567s 8s/step - loss: 1.2759 - premask_branch_1bn1_loss: 0.5764 - labels_branch_1bn1_loss: 0.6995Exception!!!
# Exception!!!
#    1078/Unknown - 8589s 8s/step - loss: 1.2756 - premask_branch_1bn1_loss: 0.5762 - labels_branch_1bn1_loss: 0.6994Exception!!!
#    1080/Unknown - 8609s 8s/step - loss: 1.2753 - premask_branch_1bn1_loss: 0.5760 - labels_branch_1bn1_loss: 0.6993Exception!!!
#    1090/Unknown - 8722s 8s/step - loss: 1.2743 - premask_branch_1bn1_loss: 0.5754 - labels_branch_1bn1_loss: 0.6989Exception!!!
# 1093/1093 [==============================] - 8762s 8s/step - loss: 1.2740 - premask_branch_1bn1_loss: 0.5752 - labels_branch_1bn1_loss: 0.6988 - val_loss: 0.0000e+00 - val_premask_branch_1bn1_loss: 0.0000e+00 - val_labels_branch_1bn1_loss: 0.0000e+00
# Epoch 2/100
#   19/1093 [..............................] - ETA: 16:22 - loss: 1.1485 - premask_branch_1bn1_loss: 0.4950 - labels_branch_1bn1_loss: 0.6535Exception!!!
#   22/1093 [..............................] - ETA: 16:26 - loss: 1.1470 - premask_branch_1bn1_loss: 0.4937 - labels_branch_1bn1_loss: 0.6533Exception!!!
#   27/1093 [..............................] - ETA: 16:26 - loss: 1.1469 - premask_branch_1bn1_loss: 0.4936 - labels_branch_1bn1_loss: 0.6533Exception!!!
#   30/1093 [..............................] - ETA: 16:25 - loss: 1.1454 - premask_branch_1bn1_loss: 0.4922 - labels_branch_1bn1_loss: 0.6533Exception!!!
#   36/1093 [..............................] - ETA: 16:20 - loss: 1.1429 - premask_branch_1bn1_loss: 0.4899 - labels_branch_1bn1_loss: 0.6530Exception!!!
#   46/1093 [>.............................] - ETA: 16:15 - loss: 1.1413 - premask_branch_1bn1_loss: 0.4886 - labels_branch_1bn1_loss: 0.6526Exception!!!
#   67/1093 [>.............................] - ETA: 15:58 - loss: 1.1370 - premask_branch_1bn1_loss: 0.4853 - labels_branch_1bn1_loss: 0.6517Exception!!!
#   91/1093 [=>............................] - ETA: 15:33 - loss: 1.1336 - premask_branch_1bn1_loss: 0.4830 - labels_branch_1bn1_loss: 0.6506Exception!!!
#  110/1093 [==>...........................] - ETA: 15:16 - loss: 1.1319 - premask_branch_1bn1_loss: 0.4820 - labels_branch_1bn1_loss: 0.6499Exception!!!
#  113/1093 [==>...........................] - ETA: 15:14 - loss: 1.1315 - premask_branch_1bn1_loss: 0.4816 - labels_branch_1bn1_loss: 0.6499Exception!!!
#  149/1093 [===>..........................] - ETA: 14:42 - loss: 1.1276 - premask_branch_1bn1_loss: 0.4788 - labels_branch_1bn1_loss: 0.6488Exception!!!
#  152/1093 [===>..........................] - ETA: 14:39 - loss: 1.1274 - premask_branch_1bn1_loss: 0.4787 - labels_branch_1bn1_loss: 0.6487Exception!!!
#  160/1093 [===>..........................] - ETA: 14:32 - loss: 1.1262 - premask_branch_1bn1_loss: 0.4778 - labels_branch_1bn1_loss: 0.6484Exception!!!
#  174/1093 [===>..........................] - ETA: 14:19 - loss: 1.1250 - premask_branch_1bn1_loss: 0.4771 - labels_branch_1bn1_loss: 0.6479Exception!!!
#  177/1093 [===>..........................] - ETA: 14:17 - loss: 1.1250 - premask_branch_1bn1_loss: 0.4771 - labels_branch_1bn1_loss: 0.6478Exception!!!
#  194/1093 [====>.........................] - ETA: 14:02 - loss: 1.1233 - premask_branch_1bn1_loss: 0.4760 - labels_branch_1bn1_loss: 0.6473Exception!!!
#  200/1093 [====>.........................] - ETA: 13:57 - loss: 1.1228 - premask_branch_1bn1_loss: 0.4756 - labels_branch_1bn1_loss: 0.6472Exception!!!
#  251/1093 [=====>........................] - ETA: 13:09 - loss: 1.1177 - premask_branch_1bn1_loss: 0.4720 - labels_branch_1bn1_loss: 0.6457Exception!!!
#  252/1093 [=====>........................] - ETA: 13:09 - loss: 1.1176 - premask_branch_1bn1_loss: 0.4719 - labels_branch_1bn1_loss: 0.6457Exception!!!
#  256/1093 [======>.......................] - ETA: 13:05 - loss: 1.1171 - premask_branch_1bn1_loss: 0.4716 - labels_branch_1bn1_loss: 0.6455Exception!!!
#  275/1093 [======>.......................] - ETA: 12:48 - loss: 1.1154 - premask_branch_1bn1_loss: 0.4705 - labels_branch_1bn1_loss: 0.6449Exception!!!
#  276/1093 [======>.......................] - ETA: 12:47 - loss: 1.1154 - premask_branch_1bn1_loss: 0.4705 - labels_branch_1bn1_loss: 0.6449Exception!!!
#  303/1093 [=======>......................] - ETA: 12:23 - loss: 1.1136 - premask_branch_1bn1_loss: 0.4695 - labels_branch_1bn1_loss: 0.6441Exception!!!
#  325/1093 [=======>......................] - ETA: 12:02 - loss: 1.1120 - premask_branch_1bn1_loss: 0.4683 - labels_branch_1bn1_loss: 0.6437Exception!!!
#  329/1093 [========>.....................] - ETA: 11:58 - loss: 1.1119 - premask_branch_1bn1_loss: 0.4682 - labels_branch_1bn1_loss: 0.6436Exception!!!
#  334/1093 [========>.....................] - ETA: 11:53 - loss: 1.1115 - premask_branch_1bn1_loss: 0.4680 - labels_branch_1bn1_loss: 0.6435Exception!!!
#  337/1093 [========>.....................] - ETA: 11:51 - loss: 1.1114 - premask_branch_1bn1_loss: 0.4679 - labels_branch_1bn1_loss: 0.6435Exception!!!
#  353/1093 [========>.....................] - ETA: 11:35 - loss: 1.1103 - premask_branch_1bn1_loss: 0.4673 - labels_branch_1bn1_loss: 0.6431Exception!!!
#  365/1093 [=========>....................] - ETA: 11:24 - loss: 1.1094 - premask_branch_1bn1_loss: 0.4667 - labels_branch_1bn1_loss: 0.6427Exception!!!
#  366/1093 [=========>....................] - ETA: 11:23 - loss: 1.1093 - premask_branch_1bn1_loss: 0.4666 - labels_branch_1bn1_loss: 0.6427Exception!!!
#  371/1093 [=========>....................] - ETA: 11:18 - loss: 1.1089 - premask_branch_1bn1_loss: 0.4664 - labels_branch_1bn1_loss: 0.6426Exception!!!
#  373/1093 [=========>....................] - ETA: 11:17 - loss: 1.1088 - premask_branch_1bn1_loss: 0.4663 - labels_branch_1bn1_loss: 0.6425Exception!!!
#  374/1093 [=========>....................] - ETA: 11:16 - loss: 1.1087 - premask_branch_1bn1_loss: 0.4662 - labels_branch_1bn1_loss: 0.6425Exception!!!
#  385/1093 [=========>....................] - ETA: 11:05 - loss: 1.1078 - premask_branch_1bn1_loss: 0.4656 - labels_branch_1bn1_loss: 0.6422Exception!!!
#  394/1093 [=========>....................] - ETA: 10:57 - loss: 1.1071 - premask_branch_1bn1_loss: 0.4651 - labels_branch_1bn1_loss: 0.6419Exception!!!
#  415/1093 [==========>...................] - ETA: 10:37 - loss: 1.1055 - premask_branch_1bn1_loss: 0.4641 - labels_branch_1bn1_loss: 0.6414Exception!!!
#  440/1093 [===========>..................] - ETA: 10:13 - loss: 1.1036 - premask_branch_1bn1_loss: 0.4629 - labels_branch_1bn1_loss: 0.6407Exception!!!
#  444/1093 [===========>..................] - ETA: 10:09 - loss: 1.1034 - premask_branch_1bn1_loss: 0.4628 - labels_branch_1bn1_loss: 0.6406Exception!!!
#  448/1093 [===========>..................] - ETA: 10:06 - loss: 1.1030 - premask_branch_1bn1_loss: 0.4625 - labels_branch_1bn1_loss: 0.6405Exception!!!
#  457/1093 [===========>..................] - ETA: 9:57 - loss: 1.1024 - premask_branch_1bn1_loss: 0.4622 - labels_branch_1bn1_loss: 0.6402Exception!!!
#  475/1093 [============>.................] - ETA: 9:40 - loss: 1.1012 - premask_branch_1bn1_loss: 0.4614 - labels_branch_1bn1_loss: 0.6397Exception!!!
#  523/1093 [=============>................] - ETA: 8:55 - loss: 1.0975 - premask_branch_1bn1_loss: 0.4590 - labels_branch_1bn1_loss: 0.6385Exception!!!
#  531/1093 [=============>................] - ETA: 8:47 - loss: 1.0969 - premask_branch_1bn1_loss: 0.4587 - labels_branch_1bn1_loss: 0.6383Exception!!!
#  534/1093 [=============>................] - ETA: 8:44 - loss: 1.0967 - premask_branch_1bn1_loss: 0.4585 - labels_branch_1bn1_loss: 0.6382Exception!!!
#  556/1093 [==============>...............] - ETA: 8:24 - loss: 1.0949 - premask_branch_1bn1_loss: 0.4573 - labels_branch_1bn1_loss: 0.6376Exception!!!
#  568/1093 [==============>...............] - ETA: 8:12 - loss: 1.0941 - premask_branch_1bn1_loss: 0.4568 - labels_branch_1bn1_loss: 0.6373Exception!!!
#  579/1093 [==============>...............] - ETA: 8:02 - loss: 1.0932 - premask_branch_1bn1_loss: 0.4562 - labels_branch_1bn1_loss: 0.6370Exception!!!
#  591/1093 [===============>..............] - ETA: 7:51 - loss: 1.0924 - premask_branch_1bn1_loss: 0.4557 - labels_branch_1bn1_loss: 0.6366Exception!!!
#  598/1093 [===============>..............] - ETA: 7:44 - loss: 1.0920 - premask_branch_1bn1_loss: 0.4555 - labels_branch_1bn1_loss: 0.6365Exception!!!
# Exception!!!
#  610/1093 [===============>..............] - ETA: 7:33 - loss: 1.0910 - premask_branch_1bn1_loss: 0.4549 - labels_branch_1bn1_loss: 0.6362Exception!!!
#  613/1093 [===============>..............] - ETA: 7:30 - loss: 1.0908 - premask_branch_1bn1_loss: 0.4547 - labels_branch_1bn1_loss: 0.6361Exception!!!
#  616/1093 [===============>..............] - ETA: 7:27 - loss: 1.0905 - premask_branch_1bn1_loss: 0.4545 - labels_branch_1bn1_loss: 0.6360Exception!!!
#  620/1093 [================>.............] - ETA: 7:23 - loss: 1.0902 - premask_branch_1bn1_loss: 0.4544 - labels_branch_1bn1_loss: 0.6359Exception!!!
#  643/1093 [================>.............] - ETA: 7:02 - loss: 1.0886 - premask_branch_1bn1_loss: 0.4533 - labels_branch_1bn1_loss: 0.6353Exception!!!
#  656/1093 [=================>............] - ETA: 6:50 - loss: 1.0876 - premask_branch_1bn1_loss: 0.4527 - labels_branch_1bn1_loss: 0.6350Exception!!!
#  677/1093 [=================>............] - ETA: 6:30 - loss: 1.0861 - premask_branch_1bn1_loss: 0.4517 - labels_branch_1bn1_loss: 0.6344Exception!!!
#  683/1093 [=================>............] - ETA: 6:24 - loss: 1.0856 - premask_branch_1bn1_loss: 0.4514 - labels_branch_1bn1_loss: 0.6343Exception!!!
#  698/1093 [==================>...........] - ETA: 6:10 - loss: 1.0845 - premask_branch_1bn1_loss: 0.4507 - labels_branch_1bn1_loss: 0.6339Exception!!!
#  709/1093 [==================>...........] - ETA: 6:00 - loss: 1.0838 - premask_branch_1bn1_loss: 0.4502 - labels_branch_1bn1_loss: 0.6336Exception!!!
#  716/1093 [==================>...........] - ETA: 5:53 - loss: 1.0833 - premask_branch_1bn1_loss: 0.4499 - labels_branch_1bn1_loss: 0.6334Exception!!!
#  732/1093 [===================>..........] - ETA: 5:38 - loss: 1.0821 - premask_branch_1bn1_loss: 0.4492 - labels_branch_1bn1_loss: 0.6330Exception!!!
#  734/1093 [===================>..........] - ETA: 5:36 - loss: 1.0820 - premask_branch_1bn1_loss: 0.4491 - labels_branch_1bn1_loss: 0.6329Exception!!!
#  736/1093 [===================>..........] - ETA: 5:35 - loss: 1.0818 - premask_branch_1bn1_loss: 0.4490 - labels_branch_1bn1_loss: 0.6328Exception!!!
#  738/1093 [===================>..........] - ETA: 5:33 - loss: 1.0817 - premask_branch_1bn1_loss: 0.4489 - labels_branch_1bn1_loss: 0.6328Exception!!!
#  742/1093 [===================>..........] - ETA: 5:29 - loss: 1.0814 - premask_branch_1bn1_loss: 0.4488 - labels_branch_1bn1_loss: 0.6327Exception!!!
#  757/1093 [===================>..........] - ETA: 5:15 - loss: 1.0804 - premask_branch_1bn1_loss: 0.4481 - labels_branch_1bn1_loss: 0.6323Exception!!!
#  759/1093 [===================>..........] - ETA: 5:13 - loss: 1.0803 - premask_branch_1bn1_loss: 0.4480 - labels_branch_1bn1_loss: 0.6322Exception!!!
#  778/1093 [====================>.........] - ETA: 4:55 - loss: 1.0795 - premask_branch_1bn1_loss: 0.4477 - labels_branch_1bn1_loss: 0.6317Exception!!!
#  784/1093 [====================>.........] - ETA: 4:50 - loss: 1.0791 - premask_branch_1bn1_loss: 0.4475 - labels_branch_1bn1_loss: 0.6316Exception!!!
#  792/1093 [====================>.........] - ETA: 4:42 - loss: 1.0786 - premask_branch_1bn1_loss: 0.4473 - labels_branch_1bn1_loss: 0.6314Exception!!!
#  796/1093 [====================>.........] - ETA: 4:39 - loss: 1.0784 - premask_branch_1bn1_loss: 0.4471 - labels_branch_1bn1_loss: 0.6313Exception!!!
#  799/1093 [====================>.........] - ETA: 4:36 - loss: 1.0782 - premask_branch_1bn1_loss: 0.4470 - labels_branch_1bn1_loss: 0.6313Exception!!!
# Exception!!!
#  801/1093 [====================>.........] - ETA: 4:34 - loss: 1.0781 - premask_branch_1bn1_loss: 0.4469 - labels_branch_1bn1_loss: 0.6312Exception!!!
#  819/1093 [=====================>........] - ETA: 4:17 - loss: 1.0769 - premask_branch_1bn1_loss: 0.4461 - labels_branch_1bn1_loss: 0.6308Exception!!!
#  821/1093 [=====================>........] - ETA: 4:15 - loss: 1.0768 - premask_branch_1bn1_loss: 0.4460 - labels_branch_1bn1_loss: 0.6308Exception!!!
#  825/1093 [=====================>........] - ETA: 4:12 - loss: 1.0766 - premask_branch_1bn1_loss: 0.4459 - labels_branch_1bn1_loss: 0.6307Exception!!!
#  828/1093 [=====================>........] - ETA: 4:09 - loss: 1.0764 - premask_branch_1bn1_loss: 0.4458 - labels_branch_1bn1_loss: 0.6306Exception!!!
#  833/1093 [=====================>........] - ETA: 4:04 - loss: 1.0760 - premask_branch_1bn1_loss: 0.4456 - labels_branch_1bn1_loss: 0.6305Exception!!!
#  847/1093 [======================>.......] - ETA: 3:51 - loss: 1.0751 - premask_branch_1bn1_loss: 0.4450 - labels_branch_1bn1_loss: 0.6301Exception!!!
#  866/1093 [======================>.......] - ETA: 3:33 - loss: 1.0740 - premask_branch_1bn1_loss: 0.4443 - labels_branch_1bn1_loss: 0.6297Exception!!!
#  948/1093 [=========================>....] - ETA: 2:16 - loss: 1.0688 - premask_branch_1bn1_loss: 0.4412 - labels_branch_1bn1_loss: 0.6276Exception!!!
#  950/1093 [=========================>....] - ETA: 2:14 - loss: 1.0686 - premask_branch_1bn1_loss: 0.4411 - labels_branch_1bn1_loss: 0.6275Exception!!!
#  956/1093 [=========================>....] - ETA: 2:08 - loss: 1.0683 - premask_branch_1bn1_loss: 0.4409 - labels_branch_1bn1_loss: 0.6274Exception!!!
#  970/1093 [=========================>....] - ETA: 1:55 - loss: 1.0674 - premask_branch_1bn1_loss: 0.4404 - labels_branch_1bn1_loss: 0.6270Exception!!!
#  979/1093 [=========================>....] - ETA: 1:47 - loss: 1.0669 - premask_branch_1bn1_loss: 0.4401 - labels_branch_1bn1_loss: 0.6268Exception!!!
#  982/1093 [=========================>....] - ETA: 1:44 - loss: 1.0667 - premask_branch_1bn1_loss: 0.4399 - labels_branch_1bn1_loss: 0.6267Exception!!!
# 1007/1093 [==========================>...] - ETA: 1:20 - loss: 1.0650 - premask_branch_1bn1_loss: 0.4389 - labels_branch_1bn1_loss: 0.6261Exception!!!
# 1012/1093 [==========================>...] - ETA: 1:16 - loss: 1.0647 - premask_branch_1bn1_loss: 0.4387 - labels_branch_1bn1_loss: 0.6260Exception!!!
# 1025/1093 [===========================>..] - ETA: 1:03 - loss: 1.0638 - premask_branch_1bn1_loss: 0.4381 - labels_branch_1bn1_loss: 0.6256Exception!!!
# 1032/1093 [===========================>..] - ETA: 57s - loss: 1.0633 - premask_branch_1bn1_loss: 0.4378 - labels_branch_1bn1_loss: 0.6255Exception!!!
# 1044/1093 [===========================>..] - ETA: 46s - loss: 1.0625 - premask_branch_1bn1_loss: 0.4373 - labels_branch_1bn1_loss: 0.6251Exception!!!
# 1073/1093 [============================>.] - ETA: 18s - loss: 1.0605 - premask_branch_1bn1_loss: 0.4361 - labels_branch_1bn1_loss: 0.6244Exception!!!
# 1093/1093 [==============================] - 1037s 948ms/step - loss: 1.0593 - premask_branch_1bn1_loss: 0.4354 - labels_branch_1bn1_loss: 0.6239 - val_loss: 0.0000e+00 - val_premask_branch_1bn1_loss: 0.0000e+00 - val_labels_branch_1bn1_loss: 0.0000e+00
# Epoch 3/100
#    1/1093 [..............................] - ETA: 1:32 - loss: 0.9815 - premask_branch_1bn1_loss: 0.3845 - labels_branch_1bn1_loss: 0.5970Exception!!!
#   26/1093 [..............................] - ETA: 16:29 - loss: 0.9842 - premask_branch_1bn1_loss: 0.3887 - labels_branch_1bn1_loss: 0.5955Exception!!!
#   43/1093 [>.............................] - ETA: 16:16 - loss: 0.9833 - premask_branch_1bn1_loss: 0.3881 - labels_branch_1bn1_loss: 0.5951Exception!!!
#   61/1093 [>.............................] - ETA: 15:59 - loss: 0.9817 - premask_branch_1bn1_loss: 0.3870 - labels_branch_1bn1_loss: 0.5946Exception!!!
#   66/1093 [>.............................] - ETA: 16:00 - loss: 0.9816 - premask_branch_1bn1_loss: 0.3870 - labels_branch_1bn1_loss: 0.5946Exception!!!
#  101/1093 [=>............................] - ETA: 15:27 - loss: 0.9835 - premask_branch_1bn1_loss: 0.3897 - labels_branch_1bn1_loss: 0.5938Exception!!!
#  115/1093 [==>...........................] - ETA: 15:15 - loss: 0.9823 - premask_branch_1bn1_loss: 0.3888 - labels_branch_1bn1_loss: 0.5934Exception!!!
#  119/1093 [==>...........................] - ETA: 15:12 - loss: 0.9820 - premask_branch_1bn1_loss: 0.3887 - labels_branch_1bn1_loss: 0.5933Exception!!!
#  128/1093 [==>...........................] - ETA: 15:05 - loss: 0.9811 - premask_branch_1bn1_loss: 0.3880 - labels_branch_1bn1_loss: 0.5931Exception!!!
#  165/1093 [===>..........................] - ETA: 14:33 - loss: 0.9780 - premask_branch_1bn1_loss: 0.3860 - labels_branch_1bn1_loss: 0.5920Exception!!!
#  181/1093 [===>..........................] - ETA: 14:20 - loss: 0.9772 - premask_branch_1bn1_loss: 0.3856 - labels_branch_1bn1_loss: 0.5916Exception!!!
#  183/1093 [====>.........................] - ETA: 14:18 - loss: 0.9772 - premask_branch_1bn1_loss: 0.3856 - labels_branch_1bn1_loss: 0.5915Exception!!!
#  186/1093 [====>.........................] - ETA: 14:15 - loss: 0.9769 - premask_branch_1bn1_loss: 0.3854 - labels_branch_1bn1_loss: 0.5915Exception!!!
#  188/1093 [====>.........................] - ETA: 14:14 - loss: 0.9770 - premask_branch_1bn1_loss: 0.3855 - labels_branch_1bn1_loss: 0.5914Exception!!!
#  207/1093 [====>.........................] - ETA: 13:58 - loss: 0.9761 - premask_branch_1bn1_loss: 0.3852 - labels_branch_1bn1_loss: 0.5909Exception!!!
#  221/1093 [=====>........................] - ETA: 13:46 - loss: 0.9750 - premask_branch_1bn1_loss: 0.3844 - labels_branch_1bn1_loss: 0.5906Exception!!!
# Exception!!!
#  245/1093 [=====>........................] - ETA: 13:23 - loss: 0.9739 - premask_branch_1bn1_loss: 0.3838 - labels_branch_1bn1_loss: 0.5901Exception!!!
#  254/1093 [=====>........................] - ETA: 13:15 - loss: 0.9733 - premask_branch_1bn1_loss: 0.3834 - labels_branch_1bn1_loss: 0.5899Exception!!!
#  287/1093 [======>.......................] - ETA: 12:42 - loss: 0.9712 - premask_branch_1bn1_loss: 0.3821 - labels_branch_1bn1_loss: 0.5891Exception!!!
#  315/1093 [=======>......................] - ETA: 12:15 - loss: 0.9696 - premask_branch_1bn1_loss: 0.3813 - labels_branch_1bn1_loss: 0.5884Exception!!!
#  323/1093 [=======>......................] - ETA: 12:08 - loss: 0.9691 - premask_branch_1bn1_loss: 0.3809 - labels_branch_1bn1_loss: 0.5882Exception!!!
#  336/1093 [========>.....................] - ETA: 11:55 - loss: 0.9684 - premask_branch_1bn1_loss: 0.3806 - labels_branch_1bn1_loss: 0.5879Exception!!!
# Exception!!!
#  346/1093 [========>.....................] - ETA: 11:46 - loss: 0.9680 - premask_branch_1bn1_loss: 0.3804 - labels_branch_1bn1_loss: 0.5876Exception!!!
#  350/1093 [========>.....................] - ETA: 11:43 - loss: 0.9677 - premask_branch_1bn1_loss: 0.3802 - labels_branch_1bn1_loss: 0.5875Exception!!!
#  352/1093 [========>.....................] - ETA: 11:41 - loss: 0.9676 - premask_branch_1bn1_loss: 0.3801 - labels_branch_1bn1_loss: 0.5875Exception!!!
#  361/1093 [========>.....................] - ETA: 11:32 - loss: 0.9671 - premask_branch_1bn1_loss: 0.3798 - labels_branch_1bn1_loss: 0.5873Exception!!!
#  376/1093 [=========>....................] - ETA: 11:18 - loss: 0.9664 - premask_branch_1bn1_loss: 0.3795 - labels_branch_1bn1_loss: 0.5869Exception!!!
#  388/1093 [=========>....................] - ETA: 11:06 - loss: 0.9655 - premask_branch_1bn1_loss: 0.3789 - labels_branch_1bn1_loss: 0.5866Exception!!!
#  390/1093 [=========>....................] - ETA: 11:04 - loss: 0.9654 - premask_branch_1bn1_loss: 0.3789 - labels_branch_1bn1_loss: 0.5865Exception!!!
#  395/1093 [=========>....................] - ETA: 10:59 - loss: 0.9651 - premask_branch_1bn1_loss: 0.3787 - labels_branch_1bn1_loss: 0.5864Exception!!!
#  407/1093 [==========>...................] - ETA: 10:48 - loss: 0.9647 - premask_branch_1bn1_loss: 0.3785 - labels_branch_1bn1_loss: 0.5861Exception!!!
#  410/1093 [==========>...................] - ETA: 10:45 - loss: 0.9644 - premask_branch_1bn1_loss: 0.3784 - labels_branch_1bn1_loss: 0.5860Exception!!!
#  411/1093 [==========>...................] - ETA: 10:44 - loss: 0.9643 - premask_branch_1bn1_loss: 0.3783 - labels_branch_1bn1_loss: 0.5860Exception!!!
#  429/1093 [==========>...................] - ETA: 10:27 - loss: 0.9633 - premask_branch_1bn1_loss: 0.3777 - labels_branch_1bn1_loss: 0.5856Exception!!!
#  431/1093 [==========>...................] - ETA: 10:25 - loss: 0.9632 - premask_branch_1bn1_loss: 0.3776 - labels_branch_1bn1_loss: 0.5855Exception!!!
#  432/1093 [==========>...................] - ETA: 10:24 - loss: 0.9631 - premask_branch_1bn1_loss: 0.3776 - labels_branch_1bn1_loss: 0.5855Exception!!!
#  434/1093 [==========>...................] - ETA: 10:22 - loss: 0.9630 - premask_branch_1bn1_loss: 0.3775 - labels_branch_1bn1_loss: 0.5855Exception!!!
#  452/1093 [===========>..................] - ETA: 10:05 - loss: 0.9621 - premask_branch_1bn1_loss: 0.3770 - labels_branch_1bn1_loss: 0.5850Exception!!!
#  476/1093 [============>.................] - ETA: 9:42 - loss: 0.9608 - premask_branch_1bn1_loss: 0.3763 - labels_branch_1bn1_loss: 0.5845Exception!!!
#  478/1093 [============>.................] - ETA: 9:40 - loss: 0.9607 - premask_branch_1bn1_loss: 0.3763 - labels_branch_1bn1_loss: 0.5844Exception!!!
#  494/1093 [============>.................] - ETA: 9:25 - loss: 0.9599 - premask_branch_1bn1_loss: 0.3759 - labels_branch_1bn1_loss: 0.5840Exception!!!
#  516/1093 [=============>................] - ETA: 9:04 - loss: 0.9585 - premask_branch_1bn1_loss: 0.3750 - labels_branch_1bn1_loss: 0.5835Exception!!!
#  519/1093 [=============>................] - ETA: 9:01 - loss: 0.9583 - premask_branch_1bn1_loss: 0.3749 - labels_branch_1bn1_loss: 0.5834Exception!!!
#  549/1093 [==============>...............] - ETA: 8:32 - loss: 0.9565 - premask_branch_1bn1_loss: 0.3739 - labels_branch_1bn1_loss: 0.5826Exception!!!
#  565/1093 [==============>...............] - ETA: 8:17 - loss: 0.9556 - premask_branch_1bn1_loss: 0.3734 - labels_branch_1bn1_loss: 0.5822Exception!!!
#  577/1093 [==============>...............] - ETA: 8:06 - loss: 0.9548 - premask_branch_1bn1_loss: 0.3729 - labels_branch_1bn1_loss: 0.5819Exception!!!
#  596/1093 [===============>..............] - ETA: 7:48 - loss: 0.9538 - premask_branch_1bn1_loss: 0.3723 - labels_branch_1bn1_loss: 0.5814Exception!!!
#  617/1093 [===============>..............] - ETA: 7:28 - loss: 0.9525 - premask_branch_1bn1_loss: 0.3717 - labels_branch_1bn1_loss: 0.5809Exception!!!
#  628/1093 [================>.............] - ETA: 7:18 - loss: 0.9520 - premask_branch_1bn1_loss: 0.3714 - labels_branch_1bn1_loss: 0.5806Exception!!!
#  644/1093 [================>.............] - ETA: 7:03 - loss: 0.9512 - premask_branch_1bn1_loss: 0.3710 - labels_branch_1bn1_loss: 0.5802Exception!!!
#  673/1093 [=================>............] - ETA: 6:35 - loss: 0.9497 - premask_branch_1bn1_loss: 0.3702 - labels_branch_1bn1_loss: 0.5795Exception!!!
#  680/1093 [=================>............] - ETA: 6:29 - loss: 0.9493 - premask_branch_1bn1_loss: 0.3700 - labels_branch_1bn1_loss: 0.5793Exception!!!
#  702/1093 [==================>...........] - ETA: 6:08 - loss: 0.9482 - premask_branch_1bn1_loss: 0.3695 - labels_branch_1bn1_loss: 0.5787Exception!!!
#  715/1093 [==================>...........] - ETA: 5:56 - loss: 0.9475 - premask_branch_1bn1_loss: 0.3691 - labels_branch_1bn1_loss: 0.5784Exception!!!
#  723/1093 [==================>...........] - ETA: 5:48 - loss: 0.9471 - premask_branch_1bn1_loss: 0.3689 - labels_branch_1bn1_loss: 0.5782Exception!!!
#  730/1093 [===================>..........] - ETA: 5:41 - loss: 0.9468 - premask_branch_1bn1_loss: 0.3688 - labels_branch_1bn1_loss: 0.5780Exception!!!
#  744/1093 [===================>..........] - ETA: 5:28 - loss: 0.9461 - premask_branch_1bn1_loss: 0.3684 - labels_branch_1bn1_loss: 0.5777Exception!!!
# Exception!!!
#  750/1093 [===================>..........] - ETA: 5:23 - loss: 0.9457 - premask_branch_1bn1_loss: 0.3682 - labels_branch_1bn1_loss: 0.5775Exception!!!
#  759/1093 [===================>..........] - ETA: 5:14 - loss: 0.9452 - premask_branch_1bn1_loss: 0.3680 - labels_branch_1bn1_loss: 0.5773Exception!!!
#  772/1093 [====================>.........] - ETA: 5:02 - loss: 0.9446 - premask_branch_1bn1_loss: 0.3676 - labels_branch_1bn1_loss: 0.5770Exception!!!
#  777/1093 [====================>.........] - ETA: 4:57 - loss: 0.9443 - premask_branch_1bn1_loss: 0.3675 - labels_branch_1bn1_loss: 0.5768Exception!!!
#  778/1093 [====================>.........] - ETA: 4:56 - loss: 0.9443 - premask_branch_1bn1_loss: 0.3675 - labels_branch_1bn1_loss: 0.5768Exception!!!
#  779/1093 [====================>.........] - ETA: 4:55 - loss: 0.9442 - premask_branch_1bn1_loss: 0.3674 - labels_branch_1bn1_loss: 0.5768Exception!!!
#  786/1093 [====================>.........] - ETA: 4:49 - loss: 0.9438 - premask_branch_1bn1_loss: 0.3672 - labels_branch_1bn1_loss: 0.5766Exception!!!
#  789/1093 [====================>.........] - ETA: 4:46 - loss: 0.9437 - premask_branch_1bn1_loss: 0.3672 - labels_branch_1bn1_loss: 0.5765Exception!!!
#  798/1093 [====================>.........] - ETA: 4:37 - loss: 0.9433 - premask_branch_1bn1_loss: 0.3670 - labels_branch_1bn1_loss: 0.5763Exception!!!
#  817/1093 [=====================>........] - ETA: 4:19 - loss: 0.9424 - premask_branch_1bn1_loss: 0.3666 - labels_branch_1bn1_loss: 0.5759Exception!!!
#  823/1093 [=====================>........] - ETA: 4:14 - loss: 0.9421 - premask_branch_1bn1_loss: 0.3664 - labels_branch_1bn1_loss: 0.5757Exception!!!
#  824/1093 [=====================>........] - ETA: 4:13 - loss: 0.9421 - premask_branch_1bn1_loss: 0.3664 - labels_branch_1bn1_loss: 0.5757Exception!!!
#  851/1093 [======================>.......] - ETA: 3:47 - loss: 0.9407 - premask_branch_1bn1_loss: 0.3657 - labels_branch_1bn1_loss: 0.5750Exception!!!
#  878/1093 [=======================>......] - ETA: 3:22 - loss: 0.9392 - premask_branch_1bn1_loss: 0.3649 - labels_branch_1bn1_loss: 0.5743Exception!!!
#  879/1093 [=======================>......] - ETA: 3:21 - loss: 0.9391 - premask_branch_1bn1_loss: 0.3648 - labels_branch_1bn1_loss: 0.5743Exception!!!
#  897/1093 [=======================>......] - ETA: 3:04 - loss: 0.9383 - premask_branch_1bn1_loss: 0.3645 - labels_branch_1bn1_loss: 0.5738Exception!!!
# Exception!!!
#  900/1093 [=======================>......] - ETA: 3:01 - loss: 0.9382 - premask_branch_1bn1_loss: 0.3644 - labels_branch_1bn1_loss: 0.5738Exception!!!
#  922/1093 [========================>.....] - ETA: 2:40 - loss: 0.9371 - premask_branch_1bn1_loss: 0.3639 - labels_branch_1bn1_loss: 0.5732Exception!!!
#  928/1093 [========================>.....] - ETA: 2:35 - loss: 0.9367 - premask_branch_1bn1_loss: 0.3637 - labels_branch_1bn1_loss: 0.5730Exception!!!
# Exception!!!
#  930/1093 [========================>.....] - ETA: 2:33 - loss: 0.9366 - premask_branch_1bn1_loss: 0.3636 - labels_branch_1bn1_loss: 0.5730Exception!!!
#  955/1093 [=========================>....] - ETA: 2:09 - loss: 0.9353 - premask_branch_1bn1_loss: 0.3630 - labels_branch_1bn1_loss: 0.5724Exception!!!
#  956/1093 [=========================>....] - ETA: 2:08 - loss: 0.9353 - premask_branch_1bn1_loss: 0.3629 - labels_branch_1bn1_loss: 0.5723Exception!!!
# Exception!!!
#  969/1093 [=========================>....] - ETA: 1:56 - loss: 0.9346 - premask_branch_1bn1_loss: 0.3626 - labels_branch_1bn1_loss: 0.5720Exception!!!
#  988/1093 [==========================>...] - ETA: 1:38 - loss: 0.9335 - premask_branch_1bn1_loss: 0.3620 - labels_branch_1bn1_loss: 0.5715Exception!!!
#  991/1093 [==========================>...] - ETA: 1:35 - loss: 0.9334 - premask_branch_1bn1_loss: 0.3620 - labels_branch_1bn1_loss: 0.5714Exception!!!
#  994/1093 [==========================>...] - ETA: 1:33 - loss: 0.9333 - premask_branch_1bn1_loss: 0.3619 - labels_branch_1bn1_loss: 0.5714Exception!!!
# 1042/1093 [===========================>..] - ETA: 47s - loss: 0.9312 - premask_branch_1bn1_loss: 0.3610 - labels_branch_1bn1_loss: 0.5702Exception!!!
# 1050/1093 [===========================>..] - ETA: 40s - loss: 0.9309 - premask_branch_1bn1_loss: 0.3608 - labels_branch_1bn1_loss: 0.5700Exception!!!
# 1064/1093 [============================>.] - ETA: 27s - loss: 0.9302 - premask_branch_1bn1_loss: 0.3605 - labels_branch_1bn1_loss: 0.5697Exception!!!
# 1087/1093 [============================>.] - ETA: 5s - loss: 0.9292 - premask_branch_1bn1_loss: 0.3600 - labels_branch_1bn1_loss: 0.5692Exception!!!
# 1093/1093 [==============================] - 1034s 946ms/step - loss: 0.9290 - premask_branch_1bn1_loss: 0.3600 - labels_branch_1bn1_loss: 0.5691 - val_loss: 0.0000e+00 - val_premask_branch_1bn1_loss: 0.0000e+00 - val_labels_branch_1bn1_loss: 0.0000e+00
# Epoch 4/100
#   22/1093 [..............................] - ETA: 16:44 - loss: 0.8725 - premask_branch_1bn1_loss: 0.3303 - labels_branch_1bn1_loss: 0.5421Exception!!!
#   45/1093 [>.............................] - ETA: 16:36 - loss: 0.8703 - premask_branch_1bn1_loss: 0.3292 - labels_branch_1bn1_loss: 0.5411Exception!!!
#   49/1093 [>.............................] - ETA: 16:37 - loss: 0.8702 - premask_branch_1bn1_loss: 0.3294 - labels_branch_1bn1_loss: 0.5408Exception!!!
#   57/1093 [>.............................] - ETA: 16:27 - loss: 0.8701 - premask_branch_1bn1_loss: 0.3296 - labels_branch_1bn1_loss: 0.5406Exception!!!
#   74/1093 [=>............................] - ETA: 16:15 - loss: 0.8692 - premask_branch_1bn1_loss: 0.3292 - labels_branch_1bn1_loss: 0.5400Exception!!!
#   98/1093 [=>............................] - ETA: 15:46 - loss: 0.8679 - premask_branch_1bn1_loss: 0.3284 - labels_branch_1bn1_loss: 0.5395Exception!!!
#  105/1093 [=>............................] - ETA: 15:39 - loss: 0.8672 - premask_branch_1bn1_loss: 0.3279 - labels_branch_1bn1_loss: 0.5393Exception!!!
#  140/1093 [==>...........................] - ETA: 15:03 - loss: 0.8649 - premask_branch_1bn1_loss: 0.3266 - labels_branch_1bn1_loss: 0.5383Exception!!!
#  146/1093 [===>..........................] - ETA: 14:58 - loss: 0.8643 - premask_branch_1bn1_loss: 0.3262 - labels_branch_1bn1_loss: 0.5381Exception!!!
#  154/1093 [===>..........................] - ETA: 14:51 - loss: 0.8637 - premask_branch_1bn1_loss: 0.3258 - labels_branch_1bn1_loss: 0.5379Exception!!!
#  173/1093 [===>..........................] - ETA: 14:33 - loss: 0.8634 - premask_branch_1bn1_loss: 0.3259 - labels_branch_1bn1_loss: 0.5375Exception!!!
#  174/1093 [===>..........................] - ETA: 14:32 - loss: 0.8633 - premask_branch_1bn1_loss: 0.3259 - labels_branch_1bn1_loss: 0.5374Exception!!!
#  175/1093 [===>..........................] - ETA: 14:32 - loss: 0.8634 - premask_branch_1bn1_loss: 0.3260 - labels_branch_1bn1_loss: 0.5374Exception!!!
#  183/1093 [====>.........................] - ETA: 14:24 - loss: 0.8631 - premask_branch_1bn1_loss: 0.3259 - labels_branch_1bn1_loss: 0.5372Exception!!!
#  191/1093 [====>.........................] - ETA: 14:16 - loss: 0.8626 - premask_branch_1bn1_loss: 0.3256 - labels_branch_1bn1_loss: 0.5370Exception!!!
#  192/1093 [====>.........................] - ETA: 14:16 - loss: 0.8626 - premask_branch_1bn1_loss: 0.3256 - labels_branch_1bn1_loss: 0.5370Exception!!!
# Exception!!!
# Exception!!!
#  204/1093 [====>.........................] - ETA: 14:06 - loss: 0.8621 - premask_branch_1bn1_loss: 0.3254 - labels_branch_1bn1_loss: 0.5367Exception!!!
#  214/1093 [====>.........................] - ETA: 13:56 - loss: 0.8617 - premask_branch_1bn1_loss: 0.3252 - labels_branch_1bn1_loss: 0.5365Exception!!!
#  234/1093 [=====>........................] - ETA: 13:37 - loss: 0.8604 - premask_branch_1bn1_loss: 0.3244 - labels_branch_1bn1_loss: 0.5360Exception!!!
#  251/1093 [=====>........................] - ETA: 13:21 - loss: 0.8598 - premask_branch_1bn1_loss: 0.3241 - labels_branch_1bn1_loss: 0.5357Exception!!!
#  262/1093 [======>.......................] - ETA: 13:11 - loss: 0.8596 - premask_branch_1bn1_loss: 0.3242 - labels_branch_1bn1_loss: 0.5354Exception!!!
#  264/1093 [======>.......................] - ETA: 13:09 - loss: 0.8595 - premask_branch_1bn1_loss: 0.3241 - labels_branch_1bn1_loss: 0.5354Exception!!!
#  272/1093 [======>.......................] - ETA: 13:02 - loss: 0.8590 - premask_branch_1bn1_loss: 0.3238 - labels_branch_1bn1_loss: 0.5352Exception!!!
#  298/1093 [=======>......................] - ETA: 12:39 - loss: 0.8579 - premask_branch_1bn1_loss: 0.3233 - labels_branch_1bn1_loss: 0.5346Exception!!!
#  301/1093 [=======>......................] - ETA: 12:36 - loss: 0.8577 - premask_branch_1bn1_loss: 0.3232 - labels_branch_1bn1_loss: 0.5345Exception!!!
#  347/1093 [========>.....................] - ETA: 11:52 - loss: 0.8555 - premask_branch_1bn1_loss: 0.3221 - labels_branch_1bn1_loss: 0.5334Exception!!!
#  351/1093 [========>.....................] - ETA: 11:48 - loss: 0.8553 - premask_branch_1bn1_loss: 0.3220 - labels_branch_1bn1_loss: 0.5333Exception!!!
#  356/1093 [========>.....................] - ETA: 11:44 - loss: 0.8551 - premask_branch_1bn1_loss: 0.3219 - labels_branch_1bn1_loss: 0.5332Exception!!!
#  359/1093 [========>.....................] - ETA: 11:41 - loss: 0.8549 - premask_branch_1bn1_loss: 0.3218 - labels_branch_1bn1_loss: 0.5331Exception!!!
#  363/1093 [========>.....................] - ETA: 11:38 - loss: 0.8548 - premask_branch_1bn1_loss: 0.3217 - labels_branch_1bn1_loss: 0.5330Exception!!!
#  374/1093 [=========>....................] - ETA: 11:27 - loss: 0.8540 - premask_branch_1bn1_loss: 0.3213 - labels_branch_1bn1_loss: 0.5327Exception!!!
#  375/1093 [=========>....................] - ETA: 11:27 - loss: 0.8540 - premask_branch_1bn1_loss: 0.3213 - labels_branch_1bn1_loss: 0.5327Exception!!!
#  382/1093 [=========>....................] - ETA: 11:20 - loss: 0.8537 - premask_branch_1bn1_loss: 0.3211 - labels_branch_1bn1_loss: 0.5326Exception!!!
#  388/1093 [=========>....................] - ETA: 11:15 - loss: 0.8533 - premask_branch_1bn1_loss: 0.3209 - labels_branch_1bn1_loss: 0.5324Exception!!!
#  394/1093 [=========>....................] - ETA: 11:10 - loss: 0.8529 - premask_branch_1bn1_loss: 0.3206 - labels_branch_1bn1_loss: 0.5323Exception!!!
#  399/1093 [=========>....................] - ETA: 11:05 - loss: 0.8528 - premask_branch_1bn1_loss: 0.3206 - labels_branch_1bn1_loss: 0.5322Exception!!!
#  432/1093 [==========>...................] - ETA: 10:33 - loss: 0.8515 - premask_branch_1bn1_loss: 0.3201 - labels_branch_1bn1_loss: 0.5314Exception!!!
#  448/1093 [===========>..................] - ETA: 10:18 - loss: 0.8507 - premask_branch_1bn1_loss: 0.3197 - labels_branch_1bn1_loss: 0.5310Exception!!!
#  449/1093 [===========>..................] - ETA: 10:17 - loss: 0.8507 - premask_branch_1bn1_loss: 0.3197 - labels_branch_1bn1_loss: 0.5310Exception!!!
#  465/1093 [===========>..................] - ETA: 10:02 - loss: 0.8500 - premask_branch_1bn1_loss: 0.3194 - labels_branch_1bn1_loss: 0.5306Exception!!!
#  489/1093 [============>.................] - ETA: 9:39 - loss: 0.8490 - premask_branch_1bn1_loss: 0.3189 - labels_branch_1bn1_loss: 0.5300Exception!!!
#  491/1093 [============>.................] - ETA: 9:37 - loss: 0.8488 - premask_branch_1bn1_loss: 0.3188 - labels_branch_1bn1_loss: 0.5300Exception!!!
#  498/1093 [============>.................] - ETA: 9:30 - loss: 0.8486 - premask_branch_1bn1_loss: 0.3187 - labels_branch_1bn1_loss: 0.5298Exception!!!
#  514/1093 [=============>................] - ETA: 9:15 - loss: 0.8480 - premask_branch_1bn1_loss: 0.3185 - labels_branch_1bn1_loss: 0.5295Exception!!!
#  527/1093 [=============>................] - ETA: 9:03 - loss: 0.8473 - premask_branch_1bn1_loss: 0.3181 - labels_branch_1bn1_loss: 0.5292Exception!!!
#  533/1093 [=============>................] - ETA: 8:57 - loss: 0.8473 - premask_branch_1bn1_loss: 0.3182 - labels_branch_1bn1_loss: 0.5291Exception!!!
#  545/1093 [=============>................] - ETA: 8:46 - loss: 0.8469 - premask_branch_1bn1_loss: 0.3181 - labels_branch_1bn1_loss: 0.5288Exception!!!
#  548/1093 [==============>...............] - ETA: 8:43 - loss: 0.8467 - premask_branch_1bn1_loss: 0.3180 - labels_branch_1bn1_loss: 0.5287Exception!!!
# Exception!!!
#  559/1093 [==============>...............] - ETA: 8:32 - loss: 0.8463 - premask_branch_1bn1_loss: 0.3178 - labels_branch_1bn1_loss: 0.5285Exception!!!
#  576/1093 [==============>...............] - ETA: 8:16 - loss: 0.8455 - premask_branch_1bn1_loss: 0.3173 - labels_branch_1bn1_loss: 0.5282Exception!!!
#  589/1093 [===============>..............] - ETA: 8:03 - loss: 0.8449 - premask_branch_1bn1_loss: 0.3170 - labels_branch_1bn1_loss: 0.5279Exception!!!
#  591/1093 [===============>..............] - ETA: 8:02 - loss: 0.8448 - premask_branch_1bn1_loss: 0.3170 - labels_branch_1bn1_loss: 0.5279Exception!!!
#  592/1093 [===============>..............] - ETA: 8:01 - loss: 0.8448 - premask_branch_1bn1_loss: 0.3170 - labels_branch_1bn1_loss: 0.5278Exception!!!
#  596/1093 [===============>..............] - ETA: 7:57 - loss: 0.8446 - premask_branch_1bn1_loss: 0.3169 - labels_branch_1bn1_loss: 0.5277Exception!!!
# ...
# 1090/1093 [============================>.] - ETA: 2s - loss: 0.6648 - premask_branch_1bn1_loss: 0.2372 - labels_branch_1bn1_loss: 0.4276Exception!!!
# 1093/1093 [==============================] - 1050s 960ms/step - loss: 0.6647 - premask_branch_1bn1_loss: 0.2372 - labels_branch_1bn1_loss: 0.4276 - val_loss: 0.0000e+00 - val_premask_branch_1bn1_loss: 0.0000e+00 - val_labels_branch_1bn1_loss: 0.0000e+00
# Epoch 7/100
# Exception!!!
#   18/1093 [..............................] - ETA: 16:08 - loss: 0.6313 - premask_branch_1bn1_loss: 0.2224 - labels_branch_1bn1_loss: 0.4089Exception!!!
# Exception!!!
#   20/1093 [..............................] - ETA: 16:11 - loss: 0.6313 - premask_branch_1bn1_loss: 0.2223 - labels_branch_1bn1_loss: 0.4090Exception!!!
#   27/1093 [..............................] - ETA: 16:24 - loss: 0.6285 - premask_branch_1bn1_loss: 0.2204 - labels_branch_1bn1_loss: 0.4081Exception!!!
#   30/1093 [..............................] - ETA: 16:26 - loss: 0.6287 - premask_branch_1bn1_loss: 0.2208 - labels_branch_1bn1_loss: 0.4079Exception!!!
#   37/1093 [>.............................] - ETA: 16:23 - loss: 0.6284 - premask_branch_1bn1_loss: 0.2208 - labels_branch_1bn1_loss: 0.4076Exception!!!
#   44/1093 [>.............................] - ETA: 16:16 - loss: 0.6284 - premask_branch_1bn1_loss: 0.2211 - labels_branch_1bn1_loss: 0.4073Exception!!!
#   94/1093 [=>............................] - ETA: 15:32 - loss: 0.6282 - premask_branch_1bn1_loss: 0.2218 - labels_branch_1bn1_loss: 0.4064Exception!!!
#  108/1093 [=>............................] - ETA: 15:22 - loss: 0.6276 - premask_branch_1bn1_loss: 0.2214 - labels_branch_1bn1_loss: 0.4062Exception!!!
#  118/1093 [==>...........................] - ETA: 15:15 - loss: 0.6271 - premask_branch_1bn1_loss: 0.2210 - labels_branch_1bn1_loss: 0.4061Exception!!!
# Exception!!!
#  144/1093 [==>...........................] - ETA: 14:53 - loss: 0.6253 - premask_branch_1bn1_loss: 0.2198 - labels_branch_1bn1_loss: 0.4055Exception!!!
#  146/1093 [===>..........................] - ETA: 14:51 - loss: 0.6255 - premask_branch_1bn1_loss: 0.2199 - labels_branch_1bn1_loss: 0.4055Exception!!!
#  172/1093 [===>..........................] - ETA: 14:27 - loss: 0.6251 - premask_branch_1bn1_loss: 0.2201 - labels_branch_1bn1_loss: 0.4051Exception!!!
# Exception!!!
#  179/1093 [===>..........................] - ETA: 14:22 - loss: 0.6248 - premask_branch_1bn1_loss: 0.2199 - labels_branch_1bn1_loss: 0.4049Exception!!!
#  210/1093 [====>.........................] - ETA: 13:52 - loss: 0.6234 - premask_branch_1bn1_loss: 0.2191 - labels_branch_1bn1_loss: 0.4044Exception!!!
#  215/1093 [====>.........................] - ETA: 13:48 - loss: 0.6232 - premask_branch_1bn1_loss: 0.2189 - labels_branch_1bn1_loss: 0.4043Exception!!!
#  219/1093 [=====>........................] - ETA: 13:44 - loss: 0.6230 - premask_branch_1bn1_loss: 0.2188 - labels_branch_1bn1_loss: 0.4042Exception!!!
# Exception!!!
#  222/1093 [=====>........................] - ETA: 13:41 - loss: 0.6229 - premask_branch_1bn1_loss: 0.2187 - labels_branch_1bn1_loss: 0.4041Exception!!!
#  239/1093 [=====>........................] - ETA: 13:25 - loss: 0.6233 - premask_branch_1bn1_loss: 0.2194 - labels_branch_1bn1_loss: 0.4039Exception!!!
#  246/1093 [=====>........................] - ETA: 13:19 - loss: 0.6232 - premask_branch_1bn1_loss: 0.2194 - labels_branch_1bn1_loss: 0.4038Exception!!!
#  279/1093 [======>.......................] - ETA: 12:48 - loss: 0.6223 - premask_branch_1bn1_loss: 0.2192 - labels_branch_1bn1_loss: 0.4031Exception!!!
# Exception!!!
#  286/1093 [======>.......................] - ETA: 12:42 - loss: 0.6221 - premask_branch_1bn1_loss: 0.2191 - labels_branch_1bn1_loss: 0.4030Exception!!!
#  302/1093 [=======>......................] - ETA: 12:27 - loss: 0.6217 - premask_branch_1bn1_loss: 0.2190 - labels_branch_1bn1_loss: 0.4027Exception!!!
# Exception!!!
#  325/1093 [=======>......................] - ETA: 12:05 - loss: 0.6209 - premask_branch_1bn1_loss: 0.2186 - labels_branch_1bn1_loss: 0.4023Exception!!!
#  332/1093 [========>.....................] - ETA: 11:59 - loss: 0.6208 - premask_branch_1bn1_loss: 0.2186 - labels_branch_1bn1_loss: 0.4022Exception!!!
#  335/1093 [========>.....................] - ETA: 11:56 - loss: 0.6206 - premask_branch_1bn1_loss: 0.2185 - labels_branch_1bn1_loss: 0.4021Exception!!!
#  356/1093 [========>.....................] - ETA: 11:36 - loss: 0.6208 - premask_branch_1bn1_loss: 0.2190 - labels_branch_1bn1_loss: 0.4018Exception!!!
#  367/1093 [=========>....................] - ETA: 11:25 - loss: 0.6206 - premask_branch_1bn1_loss: 0.2190 - labels_branch_1bn1_loss: 0.4016Exception!!!
#  379/1093 [=========>....................] - ETA: 11:14 - loss: 0.6203 - premask_branch_1bn1_loss: 0.2189 - labels_branch_1bn1_loss: 0.4014Exception!!!
#  380/1093 [=========>....................] - ETA: 11:13 - loss: 0.6203 - premask_branch_1bn1_loss: 0.2189 - labels_branch_1bn1_loss: 0.4014Exception!!!
#  383/1093 [=========>....................] - ETA: 11:11 - loss: 0.6203 - premask_branch_1bn1_loss: 0.2189 - labels_branch_1bn1_loss: 0.4014Exception!!!
#  392/1093 [=========>....................] - ETA: 11:02 - loss: 0.6200 - premask_branch_1bn1_loss: 0.2188 - labels_branch_1bn1_loss: 0.4012Exception!!!
#  393/1093 [=========>....................] - ETA: 11:01 - loss: 0.6200 - premask_branch_1bn1_loss: 0.2188 - labels_branch_1bn1_loss: 0.4012Exception!!!
#  410/1093 [==========>...................] - ETA: 10:45 - loss: 0.6196 - premask_branch_1bn1_loss: 0.2187 - labels_branch_1bn1_loss: 0.4009Exception!!!
#  416/1093 [==========>...................] - ETA: 10:39 - loss: 0.6196 - premask_branch_1bn1_loss: 0.2188 - labels_branch_1bn1_loss: 0.4008Exception!!!
#  445/1093 [===========>..................] - ETA: 10:12 - loss: 0.6189 - premask_branch_1bn1_loss: 0.2186 - labels_branch_1bn1_loss: 0.4003Exception!!!
#  455/1093 [===========>..................] - ETA: 10:02 - loss: 0.6187 - premask_branch_1bn1_loss: 0.2185 - labels_branch_1bn1_loss: 0.4002Exception!!!
#  498/1093 [============>.................] - ETA: 9:21 - loss: 0.6177 - premask_branch_1bn1_loss: 0.2183 - labels_branch_1bn1_loss: 0.3994Exception!!!
#  516/1093 [=============>................] - ETA: 9:04 - loss: 0.6177 - premask_branch_1bn1_loss: 0.2185 - labels_branch_1bn1_loss: 0.3992Exception!!!
#  523/1093 [=============>................] - ETA: 8:58 - loss: 0.6176 - premask_branch_1bn1_loss: 0.2185 - labels_branch_1bn1_loss: 0.3991Exception!!!
#  524/1093 [=============>................] - ETA: 8:57 - loss: 0.6176 - premask_branch_1bn1_loss: 0.2185 - labels_branch_1bn1_loss: 0.3991Exception!!!
#  541/1093 [=============>................] - ETA: 8:41 - loss: 0.6175 - premask_branch_1bn1_loss: 0.2186 - labels_branch_1bn1_loss: 0.3989Exception!!!
#  560/1093 [==============>...............] - ETA: 8:23 - loss: 0.6170 - premask_branch_1bn1_loss: 0.2184 - labels_branch_1bn1_loss: 0.3986Exception!!!
#  561/1093 [==============>...............] - ETA: 8:22 - loss: 0.6170 - premask_branch_1bn1_loss: 0.2184 - labels_branch_1bn1_loss: 0.3986Exception!!!
#  567/1093 [==============>...............] - ETA: 8:16 - loss: 0.6168 - premask_branch_1bn1_loss: 0.2183 - labels_branch_1bn1_loss: 0.3985Exception!!!
#  589/1093 [===============>..............] - ETA: 7:55 - loss: 0.6161 - premask_branch_1bn1_loss: 0.2180 - labels_branch_1bn1_loss: 0.3981Exception!!!
#  599/1093 [===============>..............] - ETA: 7:46 - loss: 0.6158 - premask_branch_1bn1_loss: 0.2179 - labels_branch_1bn1_loss: 0.3979Exception!!!
#  622/1093 [================>.............] - ETA: 7:24 - loss: 0.6151 - premask_branch_1bn1_loss: 0.2176 - labels_branch_1bn1_loss: 0.3975Exception!!!
#  642/1093 [================>.............] - ETA: 7:05 - loss: 0.6145 - premask_branch_1bn1_loss: 0.2173 - labels_branch_1bn1_loss: 0.3972Exception!!!
#  661/1093 [=================>............] - ETA: 6:47 - loss: 0.6140 - premask_branch_1bn1_loss: 0.2171 - labels_branch_1bn1_loss: 0.3969Exception!!!
#  662/1093 [=================>............] - ETA: 6:46 - loss: 0.6140 - premask_branch_1bn1_loss: 0.2171 - labels_branch_1bn1_loss: 0.3969Exception!!!
#  663/1093 [=================>............] - ETA: 6:45 - loss: 0.6140 - premask_branch_1bn1_loss: 0.2171 - labels_branch_1bn1_loss: 0.3969Exception!!!
#  667/1093 [=================>............] - ETA: 6:41 - loss: 0.6138 - premask_branch_1bn1_loss: 0.2170 - labels_branch_1bn1_loss: 0.3968Exception!!!
#  674/1093 [=================>............] - ETA: 6:35 - loss: 0.6137 - premask_branch_1bn1_loss: 0.2170 - labels_branch_1bn1_loss: 0.3967Exception!!!
#  685/1093 [=================>............] - ETA: 6:24 - loss: 0.6132 - premask_branch_1bn1_loss: 0.2167 - labels_branch_1bn1_loss: 0.3965Exception!!!
#  703/1093 [==================>...........] - ETA: 6:08 - loss: 0.6127 - premask_branch_1bn1_loss: 0.2165 - labels_branch_1bn1_loss: 0.3962Exception!!!
# Exception!!!
#  719/1093 [==================>...........] - ETA: 5:52 - loss: 0.6122 - premask_branch_1bn1_loss: 0.2163 - labels_branch_1bn1_loss: 0.3959Exception!!!
#  738/1093 [===================>..........] - ETA: 5:34 - loss: 0.6117 - premask_branch_1bn1_loss: 0.2161 - labels_branch_1bn1_loss: 0.3956Exception!!!
#  751/1093 [===================>..........] - ETA: 5:22 - loss: 0.6113 - premask_branch_1bn1_loss: 0.2159 - labels_branch_1bn1_loss: 0.3954Exception!!!
#  752/1093 [===================>..........] - ETA: 5:21 - loss: 0.6113 - premask_branch_1bn1_loss: 0.2159 - labels_branch_1bn1_loss: 0.3954Exception!!!
#  757/1093 [===================>..........] - ETA: 5:17 - loss: 0.6111 - premask_branch_1bn1_loss: 0.2158 - labels_branch_1bn1_loss: 0.3953Exception!!!
#  763/1093 [===================>..........] - ETA: 5:11 - loss: 0.6109 - premask_branch_1bn1_loss: 0.2158 - labels_branch_1bn1_loss: 0.3952Exception!!!
#  766/1093 [====================>.........] - ETA: 5:08 - loss: 0.6108 - premask_branch_1bn1_loss: 0.2157 - labels_branch_1bn1_loss: 0.3951Exception!!!
#  768/1093 [====================>.........] - ETA: 5:06 - loss: 0.6108 - premask_branch_1bn1_loss: 0.2157 - labels_branch_1bn1_loss: 0.3951Exception!!!
#  842/1093 [======================>.......] - ETA: 3:56 - loss: 0.6087 - premask_branch_1bn1_loss: 0.2148 - labels_branch_1bn1_loss: 0.3939Exception!!!
#  858/1093 [======================>.......] - ETA: 3:41 - loss: 0.6082 - premask_branch_1bn1_loss: 0.2146 - labels_branch_1bn1_loss: 0.3936Exception!!!
#  873/1093 [======================>.......] - ETA: 3:27 - loss: 0.6078 - premask_branch_1bn1_loss: 0.2144 - labels_branch_1bn1_loss: 0.3934Exception!!!
#  875/1093 [=======================>......] - ETA: 3:25 - loss: 0.6077 - premask_branch_1bn1_loss: 0.2144 - labels_branch_1bn1_loss: 0.3933Exception!!!
#  882/1093 [=======================>......] - ETA: 3:19 - loss: 0.6076 - premask_branch_1bn1_loss: 0.2143 - labels_branch_1bn1_loss: 0.3932Exception!!!
#  899/1093 [=======================>......] - ETA: 3:02 - loss: 0.6071 - premask_branch_1bn1_loss: 0.2142 - labels_branch_1bn1_loss: 0.3929Exception!!!
#  910/1093 [=======================>......] - ETA: 2:52 - loss: 0.6067 - premask_branch_1bn1_loss: 0.2140 - labels_branch_1bn1_loss: 0.3928Exception!!!
#  917/1093 [========================>.....] - ETA: 2:45 - loss: 0.6066 - premask_branch_1bn1_loss: 0.2139 - labels_branch_1bn1_loss: 0.3926Exception!!!
#  925/1093 [========================>.....] - ETA: 2:38 - loss: 0.6064 - premask_branch_1bn1_loss: 0.2138 - labels_branch_1bn1_loss: 0.3925Exception!!!
#  931/1093 [========================>.....] - ETA: 2:32 - loss: 0.6062 - premask_branch_1bn1_loss: 0.2138 - labels_branch_1bn1_loss: 0.3924Exception!!!
#  936/1093 [========================>.....] - ETA: 2:28 - loss: 0.6060 - premask_branch_1bn1_loss: 0.2137 - labels_branch_1bn1_loss: 0.3923Exception!!!
#  984/1093 [==========================>...] - ETA: 1:42 - loss: 0.6046 - premask_branch_1bn1_loss: 0.2131 - labels_branch_1bn1_loss: 0.3915Exception!!!
#  993/1093 [==========================>...] - ETA: 1:34 - loss: 0.6044 - premask_branch_1bn1_loss: 0.2130 - labels_branch_1bn1_loss: 0.3914Exception!!!
# 1007/1093 [==========================>...] - ETA: 1:21 - loss: 0.6039 - premask_branch_1bn1_loss: 0.2128 - labels_branch_1bn1_loss: 0.3911Exception!!!
# 1024/1093 [===========================>..] - ETA: 1:05 - loss: 0.6035 - premask_branch_1bn1_loss: 0.2126 - labels_branch_1bn1_loss: 0.3908Exception!!!
# 1030/1093 [===========================>..] - ETA: 59s - loss: 0.6033 - premask_branch_1bn1_loss: 0.2126 - labels_branch_1bn1_loss: 0.3907 Exception!!!
# 1033/1093 [===========================>..] - ETA: 56s - loss: 0.6032 - premask_branch_1bn1_loss: 0.2126 - labels_branch_1bn1_loss: 0.3907Exception!!!
# Exception!!!
# 1034/1093 [===========================>..] - ETA: 55s - loss: 0.6032 - premask_branch_1bn1_loss: 0.2126 - labels_branch_1bn1_loss: 0.3907Exception!!!
# 1082/1093 [============================>.] - ETA: 10s - loss: 0.6019 - premask_branch_1bn1_loss: 0.2120 - labels_branch_1bn1_loss: 0.3899Exception!!!
# 1086/1093 [============================>.] - ETA: 6s - loss: 0.6018 - premask_branch_1bn1_loss: 0.2120 - labels_branch_1bn1_loss: 0.3898Exception!!!
# 1087/1093 [============================>.] - ETA: 5s - loss: 0.6018 - premask_branch_1bn1_loss: 0.2120 - labels_branch_1bn1_loss: 0.3898Exception!!!
# 1093/1093 [==============================] - 1035s 947ms/step - loss: 0.6016 - premask_branch_1bn1_loss: 0.2119 - labels_branch_1bn1_loss: 0.3897 - val_loss: 0.0000e+00 - val_premask_branch_1bn1_loss: 0.0000e+00 - val_labels_branch_1bn1_loss: 0.0000e+00
# Epoch 8/100
#   12/1093 [..............................] - ETA: 15:44 - loss: 0.5691 - premask_branch_1bn1_loss: 0.1977 - labels_branch_1bn1_loss: 0.3714Exception!!!
#   23/1093 [..............................] - ETA: 16:04 - loss: 0.5693 - premask_branch_1bn1_loss: 0.1977 - labels_branch_1bn1_loss: 0.3716Exception!!!
#   44/1093 [>.............................] - ETA: 16:10 - loss: 0.5674 - premask_branch_1bn1_loss: 0.1964 - labels_branch_1bn1_loss: 0.3710Exception!!!
#   49/1093 [>.............................] - ETA: 16:09 - loss: 0.5671 - premask_branch_1bn1_loss: 0.1963 - labels_branch_1bn1_loss: 0.3708Exception!!!
#   60/1093 [>.............................] - ETA: 16:01 - loss: 0.5675 - premask_branch_1bn1_loss: 0.1967 - labels_branch_1bn1_loss: 0.3708Exception!!!
#   69/1093 [>.............................] - ETA: 15:56 - loss: 0.5686 - premask_branch_1bn1_loss: 0.1978 - labels_branch_1bn1_loss: 0.3708Exception!!!
# Exception!!!
#   87/1093 [=>............................] - ETA: 15:39 - loss: 0.5679 - premask_branch_1bn1_loss: 0.1974 - labels_branch_1bn1_loss: 0.3705Exception!!!
#  105/1093 [=>............................] - ETA: 15:21 - loss: 0.5676 - premask_branch_1bn1_loss: 0.1974 - labels_branch_1bn1_loss: 0.3703Exception!!!
#  115/1093 [==>...........................] - ETA: 15:13 - loss: 0.5686 - premask_branch_1bn1_loss: 0.1984 - labels_branch_1bn1_loss: 0.3702Exception!!!
#  117/1093 [==>...........................] - ETA: 15:11 - loss: 0.5685 - premask_branch_1bn1_loss: 0.1984 - labels_branch_1bn1_loss: 0.3701Exception!!!
#  125/1093 [==>...........................] - ETA: 15:04 - loss: 0.5681 - premask_branch_1bn1_loss: 0.1981 - labels_branch_1bn1_loss: 0.3699Exception!!!
#  128/1093 [==>...........................] - ETA: 15:02 - loss: 0.5684 - premask_branch_1bn1_loss: 0.1985 - labels_branch_1bn1_loss: 0.3699Exception!!!
#  129/1093 [==>...........................] - ETA: 15:02 - loss: 0.5683 - premask_branch_1bn1_loss: 0.1985 - labels_branch_1bn1_loss: 0.3699Exception!!!
#  134/1093 [==>...........................] - ETA: 14:57 - loss: 0.5682 - premask_branch_1bn1_loss: 0.1984 - labels_branch_1bn1_loss: 0.3698Exception!!!
#  148/1093 [===>..........................] - ETA: 14:43 - loss: 0.5678 - premask_branch_1bn1_loss: 0.1982 - labels_branch_1bn1_loss: 0.3696Exception!!!
#  156/1093 [===>..........................] - ETA: 14:37 - loss: 0.5674 - premask_branch_1bn1_loss: 0.1979 - labels_branch_1bn1_loss: 0.3695Exception!!!

# %%
# !nvidia-smi
# Out:
# Fri Aug 14 10:06:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P0    50W / 250W |  15561MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
wget http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run

# %%
# for i in range(len(teeth_labels)):
#     cv2.imwrite(os.path.join(temp_dir, '%s.png'% teeth_labels[i]), (masks[:,:,i]/2 + img_croped/2).astype(int))
# for j in range(len(ext_labels)):
#     cv2.imwrite(os.path.join(temp_dir, '%s.png'% ext_labels[j]), (masks[:,:,len(teeth_labels) + j]/2 + img_croped/2).astype(int))
